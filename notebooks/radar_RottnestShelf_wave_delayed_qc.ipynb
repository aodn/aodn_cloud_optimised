# %% [markdown]
# ## Access Radar Rottnest Shelf Wave Delayed Qc data in Zarr
# A jupyter notebook to show how to access and plot the AODN radar_RottnestShelf_wave_delayed_qc dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/9c6d6a0c-4983-4cb5-b119-02c11ce6af4e).

# %%
dataset_name = "radar_RottnestShelf_wave_delayed_qc"

# %%
import xarray as xr
import fsspec

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
# only run once, then restart session if needed
# !pip install uv

import os
import sys

def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

# Get the current directory of the notebook
current_dir = os.getcwd()

# Check if requirements.txt exists in the current directory
local_requirements = os.path.join(current_dir, 'requirements.txt')
if os.path.exists(local_requirements):
    requirements_path = local_requirements
else:
    # Fall back to the online requirements.txt file
    requirements_path = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/requirements.txt'

# Install packages using uv and the determined requirements file
if is_colab():
    import xarray as xr
    xr.set_options(display_style='text')
    os.system(f'uv pip install --system -r {requirements_path}')
else:
    os.system('uv venv')
    os.system(f'uv pip install -r {requirements_path}')
# Out:
# Requirement already satisfied: uv in /home/lbesnard/miniforge3/envs/AodnCloudOptimised/lib/python3.12/site-packages (0.4.18)
# Using CPython 3.12.6 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Audited 234 packages in 34ms

# %%
import requests
import os
if not os.path.exists('DataQuery.py'):
  print('Downloading DataQuery.py')
  url = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/aodn_cloud_optimised/lib/DataQuery.py'
  response = requests.get(url)
  with open('DataQuery.py', 'w') as f:
      f.write(response.text)

# %%
from DataQuery import plot_gridded_variable, create_timeseries, plot_time_coverage

# %%
# remote zarr dataset
url = f's3://aodn-cloud-optimised/{dataset_name}.zarr/'
ds = xr.open_zarr(fsspec.get_mapper(url, anon=True), chunks=None, consolidated=True)
ds
# Out:
# <xarray.Dataset> Size: 23GB
# Dimensions:                (LATITUDE: 92, LONGITUDE: 62, TIME: 41925)
# Coordinates:
#   * LATITUDE               (LATITUDE) float64 736B -30.15 -30.19 ... -33.43
#   * LONGITUDE              (LONGITUDE) float64 496B 113.2 113.2 ... 115.7 115.7
#   * TIME                   (TIME) datetime64[ns] 335kB 2010-04-01T00:30:00 .....
# Data variables: (12/13)
#     VAVH                   (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     VAVH_quality_control   (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     VDIRT                  (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     VDIRT_quality_control  (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     WPDIT                  (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     WPDIT_quality_control  (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     ...                     ...
#     WPFM_quality_control   (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     WPPE                   (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     WPPE_quality_control   (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     WPSM                   (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     WPSM_quality_control   (TIME, LATITUDE, LONGITUDE) float64 2GB ...
#     filename               (TIME) <U48 8MB ...
# Attributes: (12/39)
#     Conventions:                   CF-1.6,IMOS-1.4
#     abstract:                      The ACORN facility is producing NetCDF fil...
#     acknowledgement:               Any users of IMOS data are required to cle...
#     author:                        Cosoli, Simone
#     author_email:                  simone.cosoli@uwa.edu.au
#     citation:                      The citation in a list of references is: I...
#     ...                            ...
#     source:                        Terrestrial HF radar
#     ssr_Stations:                  Fremantle (FRE), Guilderton (GUI)
#     standard_name_vocabulary:      NetCDF Climate and Forecast (CF) Metadata ...
#     time_coverage_end:             2019-01-01T00:30:00Z
#     time_coverage_start:           2019-01-01T00:30:00Z
#     title:                         IMOS ACORN Rottnest Shelf (ROT), one hour ...

# %% [markdown]
# ## Plot time coverage

# %%
plot_time_coverage(ds, time_var="TIME")

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
plot_gridded_variable(ds, start_date='2014-11-02', var_name='VAVH', n_days=6, coastline_resolution="50m", time_name="TIME", lat_name="LATITUDE", lon_name="LONGITUDE")
# Out:
# Nearest date in dataset: <xarray.DataArray 'TIME' ()> Size: 8B
# array('2014-11-02T00:30:00.000003072', dtype='datetime64[ns]')
# Coordinates:
#     TIME     datetime64[ns] 8B 2014-11-02T00:30:00.000003072
# Attributes:
#     axis:             T
#     comment:          Given time lies at the middle of the 1 hour averaging p...
#     local_time_zone:  8.0
#     long_name:        time
#     standard_name:    time
#     valid_max:        999999.0
#     valid_min:        0.0
# Variable Long Name: sea_surface_wave_significant_height
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:880: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# CPU times: user 2.67 s, sys: 1.39 s, total: 4.06 s
# Wall time: 3.1 s
