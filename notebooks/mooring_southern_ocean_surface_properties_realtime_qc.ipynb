# %% [markdown]
# ## Access Mooring Southern Ocean Surface Properties Realtime NonQC (Parquet)
# This Jupyter notebook demonstrates how to access and plot mooring_southern_ocean_surface_properties_realtime_qc data, available as a [Parquet](https://parquet.apache.org) dataset stored on S3.
#
# 🔗 More information about the dataset is available [in the AODN metadata catalogue](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/9fdb1eee-bc28-43a9-88c5-972324784837).
#
# 📌 The source of truth for this notebook is maintained on [GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/mooring_southern_ocean_surface_properties_realtime_qc.ipynb).

# %%
dataset_name = "mooring_southern_ocean_surface_properties_realtime_qc"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()

# %%
from DataQuery import GetAodn

# %% [markdown]
# # Understanding the Dataset

# %% [markdown]
# ## Understanding Parquet Partitioning
#
# Parquet files can be **partitioned** by one or more columns, which means the data is physically organised into folders based on the values in those columns. This is similar to how databases use indexes to optimise query performance.
#
# Partitioning enables **faster filtering**: when you query data using a partitioned column, only the relevant subset of files needs to be read—improving performance significantly.
#
# For example, if a dataset is partitioned by `"site_code"`, `"timestamp"`, and `"polygon"`, filtering on `"site_code"` allows the system to skip unrelated files entirely.
#
# In this notebook, the `GetAodn` class includes built-in methods to efficiently filter data by **time** and **latitude/longitude** using the **timestamp** and **polygon** partitions. Other partitions can be used for filtering via the `scalar_filter`.
#
# Any filtering on columns that are **not** partitioned can be significantly slower, as all files may need to be scanned. However, the `GetAodn` class provides a `scalar_filter` method that lets you apply these filters at load time—before the data is fully read—helping reduce the size of the resulting DataFrame.
#
# Once the dataset is loaded, further filtering using Pandas is efficient and flexible.
#
# See further below in the notebook for examples of how to filter the data effectively.
#
# To view the actual partition columns for this dataset, run:

# %%
aodn = GetAodn()
dname = f'{dataset_name}.parquet'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 131 ms, sys: 27.3 ms, total: 159 ms
# Wall time: 9.38 s

# %%
aodn_dataset.dataset.partitioning.schema
# Out:
# deployment_number: int32
# timestamp: int32
# polygon: string

# %% [markdown]
# ## List unique partition values

# %%
# %%time
unique_partition_value = aodn_dataset.get_unique_partition_values('deployment_number')
print(list(unique_partition_value)[0:2])  # showing a subset only
# Out:
# ['1', '4']
# CPU times: user 13.8 ms, sys: 3.29 ms, total: 17.1 ms
# Wall time: 13 ms

# %% [markdown]
# ## Visualise Spatial Extent of the dataset
# This section plots the polygons representing the areas where data is available. It helps to identify and create a bounding box around the regions containing data.

# %%
aodn_dataset.plot_spatial_extent()
# Out:
# /home/lbesnard/miniforge3/envs/AodnCloudOptimised/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:143: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## Get Temporal Extent of the dataset

# %% [markdown]
# Similary to the spatial extent, we're retrieving the minimum and maximum timestamp partition values of the dataset. This is not necessarely accurately representative of the TIME values, as the timestamp partition can be yearly/monthly... but is here to give an idea

# %%
# %%time
aodn_dataset.get_temporal_extent()
# Out:
# CPU times: user 1.91 s, sys: 486 ms, total: 2.4 s
# Wall time: 16 s
# (Timestamp('2010-03-17 12:29:00.000016896'),
#  Timestamp('2017-10-23 23:59:00.000003584'))

# %% [markdown]
# ## Read Metadata
#
# For all Parquet datasets, we create a sidecar file named **_common_metadata** in the root of the dataset. This file contains both the dataset-level and variable-level attributes.
# The metadata can be retrieved below as a dictionary, and it will also be included in the pandas DataFrame when using the `get_data` method from the `GetAodn` class.

# %%
metadata = aodn_dataset.get_metadata()
metadata
# Out:
# 2025-10-29 14:35:19,618 - aodn.GetAodn - INFO - Retrieving metadata for imos-data-lab-optimised/mooring_southern_ocean_surface_properties_realtime_qc.parquet
# {'TIME': {'type': 'timestamp[ns]',
#   'standard_name': 'time',
#   'long_name': 'time',
#   'axis': 'T',
#   'valid_min': 0,
#   'valid_max': 90000.0,
#   'comment': 'Relative julian days with decimal part as parts of the day',
#   'ancillary_variables': 'TIME_quality_control'},
#  'LATITUDE': {'type': 'float',
#   'long_name': 'latitude',
#   'units': 'degrees_north',
#   'instrument': 'Iridium Satellite Tracker 9601-DGS-LP',
#   'observation_type': 'measured',
#   'standard_name': 'latitude',
#   'axis': 'Y',
#   'valid_min': -90,
#   'valid_max': 90,
#   'reference_datum': 'geographical coordinates, WGS84',
#   'ancillary_variables': 'LATITUDE_quality_control'},
#  'LONGITUDE': {'type': 'float',
#   'long_name': 'longitude',
#   'units': 'degrees_east',
#   'instrument': 'Iridium Satellite Tracker 9601-DGS-LP',
#   'observation_type': 'measured',
#   'standard_name': 'longitude',
#   'axis': 'X',
#   'valid_min': -180,
#   'valid_max': 180,
#   'reference_datum': 'geographical coordinates, WGS84',
#   'ancillary_variables': 'LONGITUDE_quality_control'},
#  'WSPD_3': {'type': 'float',
#   'long_name': 'earth relative wind speed (6580)',
#   'units': 'meter second-1',
#   'instrument': 'calculated from scalar average U and V',
#   'observation_type': 'calculated',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'wind_speed',
#   'ancillary_variables': 'WSPD_3_quality_control'},
#  'WSPD_4': {'type': 'float',
#   'long_name': 'earth relative wind speed (8670)',
#   'units': 'meter second-1',
#   'instrument': 'calculated from scalar average U and V',
#   'observation_type': 'calculated',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'wind_speed',
#   'ancillary_variables': 'WSPD_4_quality_control'},
#  'WSPD_3_quality_control': {'type': 'string',
#   'standard_name': 'wind_speed status_flag',
#   'long_name': 'quality flags for wind_speed',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'WSPD_4_quality_control': {'type': 'string',
#   'standard_name': 'wind_speed status_flag',
#   'long_name': 'quality flags for wind_speed',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'RAD_SW2': {'type': 'float',
#   'actual_range': [0.0, 0.0],
#   'long_name': 'short wave radiation (8670)',
#   'units': 'watts meter-2',
#   'original_units': 'watts meter-2',
#   'instrument': 'Eppley Precision Spectral Pyranometer (s/n 236)',
#   'rad_direction': 'downwelling',
#   'observation_type': 'measured',
#   'height': 2.809999942779541,
#   'average_method': 'average',
#   'average_center': 'time at end of period',
#   'average_length': 3600,
#   'sampling_rate': 0.016699999570846558,
#   'data_precision': 0.10000000149011612,
#   'special_value': -8888.0,
#   'qcindex': 29},
#  'RAD_LW': {'type': 'float',
#   'actual_range': [0.0, 0.0],
#   'long_name': 'long wave radiation (1260)',
#   'units': 'watts meter-2',
#   'original_units': 'watts meter-2',
#   'instrument': 'Eppley Precision Infrared Radiometer (s/n 227)',
#   'rad_direction': 'downwelling',
#   'observation_type': 'measured',
#   'height': 2.809999942779541,
#   'average_method': 'average',
#   'average_center': 'time at end of period',
#   'average_length': 3600,
#   'sampling_rate': 0.016699999570846558,
#   'data_precision': 0.10000000149011612,
#   'special_value': -8888.0,
#   'qcindex': 30},
#  'RAD_LW2': {'type': 'float',
#   'actual_range': [0.0, 0.0],
#   'long_name': 'long wave radiation (8670)',
#   'units': 'watts meter-2',
#   'original_units': 'watts meter-2',
#   'instrument': 'Eppley Precision Infrared Radiometer (s/n 228)',
#   'rad_direction': 'downwelling',
#   'observation_type': 'measured',
#   'height': 2.809999942779541,
#   'average_method': 'average',
#   'average_center': 'time at end of period',
#   'average_length': 3600,
#   'sampling_rate': 0.016699999570846558,
#   'data_precision': 0.10000000149011612,
#   'qcindex': 31},
#  'UWND': {'type': 'float',
#   'long_name': 'eastward component of wind speed (5180)',
#   'units': 'meter second-1',
#   'instrument': 'Gill Instruments Wind Observer II (s/n 213)',
#   'observation_type': 'measured',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'eastward_wind',
#   'ancillary_variables': 'UWND_quality_control'},
#  'UWND_2': {'type': 'float',
#   'long_name': 'eastward component of wind speed (5950)',
#   'units': 'meter second-1',
#   'instrument': 'Gill Instruments Wind Observer II (s/n 214)',
#   'observation_type': 'measured',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'eastward_wind',
#   'ancillary_variables': 'UWND_2_quality_control'},
#  'VWND': {'type': 'float',
#   'long_name': 'northward component of wind speed (5180)',
#   'units': 'meter second-1',
#   'instrument': 'Gill Instruments Wind Observer II (s/n 213)',
#   'observation_type': 'measured',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'northward_wind',
#   'ancillary_variables': 'VWND_quality_control'},
#  'VWND_2': {'type': 'float',
#   'long_name': 'northward component of wind speed (5950)',
#   'units': 'meter second-1',
#   'instrument': 'Gill Instruments Wind Observer II (s/n 214)',
#   'observation_type': 'measured',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'northward_wind',
#   'ancillary_variables': 'VWND_2_quality_control'},
#  'WDIR': {'type': 'float',
#   'long_name': 'earth relative wind direction (5180)',
#   'units': 'degrees (clockwise from true north)',
#   'instrument': 'calculated from U and V',
#   'observation_type': 'calculated',
#   'wind_direction_convention': 'oceanographic',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'wind_to_direction',
#   'ancillary_variables': 'WDIR_quality_control'},
#  'WDIR_2': {'type': 'float',
#   'long_name': 'earth relative wind direction (5950)',
#   'units': 'degrees (clockwise from true north)',
#   'instrument': 'calculated from U and V',
#   'observation_type': 'calculated',
#   'wind_direction_convention': 'oceanographic',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'wind_to_direction',
#   'ancillary_variables': 'WDIR_2_quality_control'},
#  'WSPD': {'type': 'float',
#   'long_name': 'earth relative wind speed (5180)',
#   'units': 'meter second-1',
#   'instrument': 'calculated from U and V',
#   'observation_type': 'calculated',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'wind_speed',
#   'ancillary_variables': 'WSPD_quality_control'},
#  'WSPD_2': {'type': 'float',
#   'long_name': 'earth relative wind speed (5950)',
#   'units': 'meter second-1',
#   'instrument': 'calculated from U and V',
#   'observation_type': 'calculated',
#   'sensor_height': 3.5199999809265137,
#   'standard_name': 'wind_speed',
#   'ancillary_variables': 'WSPD_2_quality_control'},
#  'ATMP': {'type': 'float',
#   'long_name': 'atmospheric pressure (5180)',
#   'units': 'millibar',
#   'instrument': 'Dresser Instruments Heise DXD (s/n 226)',
#   'mslp_indicator': 'at sensor height',
#   'observation_type': 'measured',
#   'sensor_height': 3.1700000762939453,
#   'standard_name': 'air_pressure',
#   'ancillary_variables': 'ATMP_quality_control'},
#  'ATMP_2': {'type': 'float',
#   'long_name': 'atmospheric pressure (5950)',
#   'units': 'millibar',
#   'instrument': 'Dresser Instruments Heise DXD (s/n 227)',
#   'mslp_indicator': 'at sensor height',
#   'observation_type': 'measured',
#   'sensor_height': 3.1700000762939453,
#   'standard_name': 'air_pressure',
#   'ancillary_variables': 'ATMP_2_quality_control'},
#  'AIRT': {'type': 'float',
#   'long_name': 'air temperature (5180)',
#   'units': 'celsius',
#   'instrument': 'Rotronic MP-101A (s/n 243)',
#   'observation_type': 'measured',
#   'sensor_height': 3.1700000762939453,
#   'standard_name': 'air_temperature',
#   'ancillary_variables': 'AIRT_quality_control'},
#  'AIRT_2': {'type': 'float',
#   'long_name': 'air temperature (5950)',
#   'units': 'celsius',
#   'instrument': 'Rotronic MP-101A (s/n 242)',
#   'observation_type': 'measured',
#   'sensor_height': 3.1700000762939453,
#   'standard_name': 'air_temperature',
#   'ancillary_variables': 'AIRT_2_quality_control'},
#  'RELH': {'type': 'float',
#   'long_name': 'relative humidity (5180)',
#   'units': 'percent',
#   'instrument': 'Rotronic MP-101A (s/n 243)',
#   'observation_type': 'measured',
#   'sensor_height': 3.1700000762939453,
#   'standard_name': 'relative_humidity',
#   'ancillary_variables': 'RELH_quality_control'},
#  'RELH_2': {'type': 'float',
#   'long_name': 'relative humidity (5950)',
#   'units': 'percent',
#   'instrument': 'Rotronic MP-101A (s/n 242)',
#   'observation_type': 'measured',
#   'sensor_height': 3.1700000762939453,
#   'standard_name': 'relative_humidity',
#   'ancillary_variables': 'RELH_2_quality_control'},
#  'TEMP': {'type': 'float',
#   'long_name': 'sea temperature (5180)',
#   'units': 'celsius',
#   'instrument': 'SBE37 (s/n 1840)',
#   'observation_type': 'measured',
#   'sensor_depth': 0.6100000143051147,
#   'standard_name': 'sea_surface_temperature',
#   'ancillary_variables': 'TEMP_quality_control'},
#  'TEMP_2': {'type': 'float',
#   'long_name': 'sea temperature (5950)',
#   'units': 'celsius',
#   'instrument': 'SBE37 (s/n 7409)',
#   'observation_type': 'measured',
#   'sensor_depth': 0.6100000143051147,
#   'standard_name': 'sea_surface_temperature',
#   'ancillary_variables': 'TEMP_2_quality_control'},
#  'CNDC': {'type': 'float',
#   'long_name': 'sea water electrical conductivity (5180)',
#   'units': 'siemens meter-1',
#   'instrument': 'SBE37 (s/n 1840)',
#   'observation_type': 'measured',
#   'sensor_depth': 0.6100000143051147,
#   'standard_name': 'sea_water_electrical_conductivity',
#   'ancillary_variables': 'CNDC_quality_control'},
#  'CNDC_2': {'type': 'float',
#   'long_name': 'sea water electrical conductivity (5950)',
#   'units': 'siemens meter-1',
#   'instrument': 'SBE37 (s/n 7409)',
#   'observation_type': 'measured',
#   'sensor_depth': 0.6100000143051147,
#   'standard_name': 'sea_water_electrical_conductivity',
#   'ancillary_variables': 'CNDC_2_quality_control'},
#  'PSAL': {'type': 'float',
#   'long_name': 'sea water salinity (5180)',
#   'units': '1e-3',
#   'instrument': 'calculated from conductivity and water temperature',
#   'observation_type': 'calculated',
#   'sensor_depth': 0.6100000143051147,
#   'standard_name': 'sea_water_salinity',
#   'ancillary_variables': 'PSAL_quality_control'},
#  'PSAL_2': {'type': 'float',
#   'long_name': 'sea water salinity (5950)',
#   'units': '1e-3',
#   'instrument': 'calculated from conductivity and water temperature',
#   'observation_type': 'calculated',
#   'sensor_depth': 0.6100000143051147,
#   'standard_name': 'sea_water_salinity',
#   'ancillary_variables': 'PSAL_2_quality_control'},
#  'RAIN_AMOUNT': {'type': 'float',
#   'long_name': 'precipitation (5180)',
#   'units': 'millimeters',
#   'instrument': 'RM Young 50202 (s/n 221)',
#   'sensor_height': 3.119999885559082,
#   'observation_type': 'measured',
#   'standard_name': 'thickness_of_rainfall_amount',
#   'ancillary_variables': 'RAIN_AMOUNT_quality_control'},
#  'RAIN_AMOUNT_2': {'type': 'float',
#   'long_name': 'precipitation (5950)',
#   'units': 'millimeters',
#   'instrument': 'RM Young 50202 (s/n 222)',
#   'sensor_height': 3.119999885559082,
#   'observation_type': 'measured',
#   'standard_name': 'thickness_of_rainfall_amount',
#   'ancillary_variables': 'RAIN_AMOUNT_2_quality_control'},
#  'SW': {'type': 'float',
#   'long_name': 'short wave radiation (5180)',
#   'units': 'watts meter-2',
#   'instrument': 'Eppley Precision Spectral Pyranometer (s/n 235)',
#   'rad_direction': 'downwelling',
#   'observation_type': 'measured',
#   'sensor_height': 3.069999933242798,
#   'standard_name': 'surface_downwelling_shortwave_flux_in_air',
#   'ancillary_variables': 'SW_quality_control'},
#  'SW_2': {'type': 'float',
#   'long_name': 'short wave radiation (5950)',
#   'units': 'watts meter-2',
#   'instrument': 'Eppley Precision Spectral Pyranometer (s/n 236)',
#   'rad_direction': 'downwelling',
#   'observation_type': 'measured',
#   'sensor_height': 3.069999933242798,
#   'standard_name': 'surface_downwelling_shortwave_flux_in_air',
#   'ancillary_variables': 'SW_2_quality_control'},
#  'LW': {'type': 'float',
#   'long_name': 'long wave radiation (5180)',
#   'units': 'watts meter-2',
#   'instrument': 'Eppley Precision Infrared Radiometer (s/n 228)',
#   'rad_direction': 'downwelling',
#   'observation_type': 'measured',
#   'sensor_height': 3.069999933242798,
#   'standard_name': 'surface_downwelling_longwave_flux_in_air',
#   'ancillary_variables': 'LW_quality_control'},
#  'LW_2': {'type': 'float',
#   'long_name': 'long wave radiation (5950)',
#   'units': 'watts meter-2',
#   'instrument': 'Eppley Precision Infrared Radiometer (s/n 227)',
#   'rad_direction': 'downwelling',
#   'observation_type': 'measured',
#   'sensor_height': 3.069999933242798,
#   'standard_name': 'surface_downwelling_longwave_flux_in_air',
#   'ancillary_variables': 'LW_2_quality_control'},
#  'PL_CMP': {'type': 'float',
#   'long_name': 'compass direction (5180)',
#   'units': 'degrees_north',
#   'instrument': '',
#   'observation_type': 'measured',
#   'ancillary_variables': 'PL_CMP_quality_control'},
#  'PL_CMP2': {'type': 'float',
#   'long_name': 'compass direction (5950)',
#   'units': 'degrees (clockwise towards true north)',
#   'instrument': '',
#   'observation_type': 'measured',
#   'ancillary_variables': 'PL_CMP2_quality_control'},
#  'history': {'type': 'string', 'long_name': 'file history information'},
#  'TIME_quality_control': {'type': 'string',
#   'standard_name': 'time status_flag',
#   'long_name': 'quality flags for time',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'LATITUDE_quality_control': {'type': 'string',
#   'standard_name': 'latitude status_flag',
#   'long_name': 'quality flags for latitude',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'LONGITUDE_quality_control': {'type': 'string',
#   'standard_name': 'longitude status_flag',
#   'long_name': 'quality flags for longitude',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'UWND_quality_control': {'type': 'string',
#   'standard_name': 'eastward_wind status_flag',
#   'long_name': 'quality flags for eastward_wind',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'UWND_2_quality_control': {'type': 'string',
#   'standard_name': 'eastward_wind status_flag',
#   'long_name': 'quality flags for eastward_wind',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'VWND_quality_control': {'type': 'string',
#   'standard_name': 'northward_wind status_flag',
#   'long_name': 'quality flags for northward_wind',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'VWND_2_quality_control': {'type': 'string',
#   'standard_name': 'northward_wind status_flag',
#   'long_name': 'quality flags for northward_wind',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'WDIR_quality_control': {'type': 'string',
#   'standard_name': 'wind_to_direction status_flag',
#   'long_name': 'quality flags for wind_to_direction',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'WDIR_2_quality_control': {'type': 'string',
#   'standard_name': 'wind_to_direction status_flag',
#   'long_name': 'quality flags for wind_to_direction',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'WSPD_quality_control': {'type': 'string',
#   'standard_name': 'wind_speed status_flag',
#   'long_name': 'quality flags for wind_speed',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'WSPD_2_quality_control': {'type': 'string',
#   'standard_name': 'wind_speed status_flag',
#   'long_name': 'quality flags for wind_speed',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'ATMP_quality_control': {'type': 'string',
#   'standard_name': 'air_pressure status_flag',
#   'long_name': 'quality flags for air_pressure',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'ATMP_2_quality_control': {'type': 'string',
#   'standard_name': 'air_pressure status_flag',
#   'long_name': 'quality flags for air_pressure',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'AIRT_quality_control': {'type': 'string',
#   'standard_name': 'air_temperature status_flag',
#   'long_name': 'quality flags for air_temperature',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'AIRT_2_quality_control': {'type': 'string',
#   'standard_name': 'air_temperature status_flag',
#   'long_name': 'quality flags for air_temperature',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'RELH_quality_control': {'type': 'string',
#   'standard_name': 'relative_humidity status_flag',
#   'long_name': 'quality flags for relative_humidity',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'RELH_2_quality_control': {'type': 'string',
#   'standard_name': 'relative_humidity status_flag',
#   'long_name': 'quality flags for relative_humidity',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'TEMP_quality_control': {'type': 'string',
#   'standard_name': 'sea_surface_temperature status_flag',
#   'long_name': 'quality flags for sea_surface_temperature',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'TEMP_2_quality_control': {'type': 'string',
#   'standard_name': 'sea_surface_temperature status_flag',
#   'long_name': 'quality flags for sea_surface_temperature',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'CNDC_quality_control': {'type': 'string',
#   'standard_name': 'sea_water_electrical_conductivity status_flag',
#   'long_name': 'quality flags for sea_water_electrical_conductivity',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'CNDC_2_quality_control': {'type': 'string',
#   'standard_name': 'sea_water_electrical_conductivity status_flag',
#   'long_name': 'quality flags for sea_water_electrical_conductivity',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'PSAL_quality_control': {'type': 'string',
#   'standard_name': 'sea_water_salinity status_flag',
#   'long_name': 'quality flags for sea_water_salinity',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'PSAL_2_quality_control': {'type': 'string',
#   'standard_name': 'sea_water_salinity status_flag',
#   'long_name': 'quality flags for sea_water_salinity',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'RAIN_AMOUNT_quality_control': {'type': 'string',
#   'standard_name': 'thickness_of_rainfall_amount status_flag',
#   'long_name': 'quality flags for thickness_of_rainfall_amount',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'RAIN_AMOUNT_2_quality_control': {'type': 'string',
#   'standard_name': 'thickness_of_rainfall_amount status_flag',
#   'long_name': 'quality flags for thickness_of_rainfall_amount',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'SW_quality_control': {'type': 'string',
#   'standard_name': 'surface_downwelling_shortwave_flux_in_air status_flag',
#   'long_name': 'quality flags for surface_downwelling_shortwave_flux_in_air',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'SW_2_quality_control': {'type': 'string',
#   'standard_name': 'surface_downwelling_shortwave_flux_in_air status_flag',
#   'long_name': 'quality flags for surface_downwelling_shortwave_flux_in_air',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'LW_quality_control': {'type': 'string',
#   'standard_name': 'surface_downwelling_longwave_flux_in_air status_flag',
#   'long_name': 'quality flags for surface_downwelling_longwave_flux_in_air',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'LW_2_quality_control': {'type': 'string',
#   'standard_name': 'surface_downwelling_longwave_flux_in_air status_flag',
#   'long_name': 'quality flags for surface_downwelling_longwave_flux_in_air',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'PL_CMP_quality_control': {'type': 'string',
#   'long_name': 'quality flags for compass direction',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'PL_CMP2_quality_control': {'type': 'string',
#   'standard_name': ' status_flag',
#   'long_name': 'quality flags for',
#   'quality_control_conventions': 'IMOS Reference Table F',
#   'quality_control_set': 3,
#   'quality_control_flag_values': 'B, C, D, E, F, G, H, J, K, L, M, Q, S, T, U, V, X, Z',
#   'quality_control_flag_meanings': 'Value_out_of_bounds Time_not_sequential Failed_T_Tw_Td_test Failed_true_wind_recomputation_test Platform_velocity_unrealistic Value_exceeds_threshold Discontinuity Erroneous_value Suspect_value_(visual) Value_located_over_land Instrument_malfunction Pre-flagged_as_suspect Spike_in_data_(visual) Time_duplicate Suspect_value_(statistical) Step_in_data_(statistical) Spike_in_data_(statistical) Value_passed_all_tests'},
#  'filename': {'type': 'string',
#   'units': '1',
#   'long_name': 'Filename of the source file'},
#  'timestamp': {'type': 'int64',
#   'units': '1',
#   'long_name': 'Partition timestamp'},
#  'deployment_number': {'type': 'float32',
#   'units': '1',
#   'long_name': 'deployment number'},
#  'polygon': {'type': 'string',
#   'units': '1',
#   'long_name': 'Spatial partition polygon'},
#  'global_attributes': {'metadata_uuid': '9fdb1eee-bc28-43a9-88c5-972324784837',
#   'dataset_name': 'mooring_southern_ocean_surface_properties_realtime_qc',
#   'title': 'IMOS - Deep Water Moorings - Southern Ocean Flux Station (SOFS) - Surface properties (real-time)',
#   'site': 'Southern Ocean Flux Station'}}

# %% [markdown]
# # Data Query and Plot

# %% [markdown]
# ## Create a TIME and BoundingBox filter
#
# This cell loads a subset of the dataset based on a time range and a spatial bounding box. The result is returned as a pandas DataFrame, and basic information about its structure is displayed.

# %%
# %%time
df = aodn_dataset.get_data(date_start='2010-03-18', 
                           date_end='2013-08-01',
                           lat_min=-55, 
                           lat_max=-40, 
                           lon_min=135, 
                           lon_max=160, 
                           )

df.info()
# Out:
# 2025-10-29 14:35:52,600 - aodn.GetAodn - INFO - Retrieving metadata for imos-data-lab-optimised/mooring_southern_ocean_surface_properties_realtime_qc.parquet
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408480 entries, 0 to 408479
# Data columns (total 74 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   TIME                           408480 non-null  datetime64[ns]
#  1   LATITUDE                       408480 non-null  float32
#  2   LONGITUDE                      408480 non-null  float32
#  3   UWND                           314640 non-null  float32
#  4   UWND_2                         398540 non-null  float32
#  5   VWND                           314640 non-null  float32
#  6   VWND_2                         398540 non-null  float32
#  7   WDIR                           408480 non-null  float32
#  8   WDIR_2                         398540 non-null  float32
#  9   WSPD                           314640 non-null  float32
#  10  WSPD_2                         398540 non-null  float32
#  11  ATMP                           314640 non-null  float32
#  12  ATMP_2                         398540 non-null  float32
#  13  AIRT                           314640 non-null  float32
#  14  AIRT_2                         398540 non-null  float32
#  15  RELH                           314640 non-null  float32
#  16  RELH_2                         398540 non-null  float32
#  17  TEMP                           314640 non-null  float32
#  18  TEMP_2                         398540 non-null  float32
#  19  CNDC                           314640 non-null  float32
#  20  CNDC_2                         398540 non-null  float32
#  21  PSAL                           314640 non-null  float32
#  22  PSAL_2                         398540 non-null  float32
#  23  RAIN_AMOUNT                    314640 non-null  float32
#  24  RAIN_AMOUNT_2                  398540 non-null  float32
#  25  SW                             314640 non-null  float32
#  26  SW_2                           398540 non-null  float32
#  27  LW                             314640 non-null  float32
#  28  LW_2                           408480 non-null  float32
#  29  PL_CMP                         314640 non-null  float32
#  30  PL_CMP2                        408480 non-null  float32
#  31  history                        408480 non-null  object
#  32  TIME_quality_control           408480 non-null  object
#  33  LATITUDE_quality_control       408480 non-null  object
#  34  LONGITUDE_quality_control      408480 non-null  object
#  35  UWND_quality_control           408480 non-null  object
#  36  UWND_2_quality_control         408480 non-null  object
#  37  VWND_quality_control           408480 non-null  object
#  38  VWND_2_quality_control         408480 non-null  object
#  39  WDIR_quality_control           408480 non-null  object
#  40  WDIR_2_quality_control         408480 non-null  object
#  41  WSPD_quality_control           408480 non-null  object
#  42  WSPD_2_quality_control         408480 non-null  object
#  43  ATMP_quality_control           408480 non-null  object
#  44  ATMP_2_quality_control         408480 non-null  object
#  45  AIRT_quality_control           408480 non-null  object
#  46  AIRT_2_quality_control         408480 non-null  object
#  47  RELH_quality_control           408480 non-null  object
#  48  RELH_2_quality_control         408480 non-null  object
#  49  TEMP_quality_control           408480 non-null  object
#  50  TEMP_2_quality_control         408480 non-null  object
#  51  CNDC_quality_control           408480 non-null  object
#  52  CNDC_2_quality_control         408480 non-null  object
#  53  PSAL_quality_control           408480 non-null  object
#  54  PSAL_2_quality_control         408480 non-null  object
#  55  RAIN_AMOUNT_quality_control    408480 non-null  object
#  56  RAIN_AMOUNT_2_quality_control  408480 non-null  object
#  57  SW_quality_control             408480 non-null  object
#  58  SW_2_quality_control           408480 non-null  object
#  59  LW_quality_control             408480 non-null  object
#  60  LW_2_quality_control           408480 non-null  object
#  61  PL_CMP_quality_control         408480 non-null  object
#  62  PL_CMP2_quality_control        408480 non-null  object
#  63  filename                       408480 non-null  object
#  64  WSPD_3                         92100 non-null   float32
#  65  WSPD_4                         97960 non-null   float32
#  66  WSPD_3_quality_control         103660 non-null  object
#  67  WSPD_4_quality_control         103660 non-null  object
#  68  RAD_SW2                        0 non-null       float32
#  69  RAD_LW                         0 non-null       float32
#  70  RAD_LW2                        0 non-null       float32
#  71  deployment_number              408480 non-null  int32
#  72  timestamp                      408480 non-null  int32
#  73  polygon                        408480 non-null  object
# dtypes: datetime64[ns](1), float32(35), int32(2), object(36)
# memory usage: 173.0+ MB
# CPU times: user 10.1 s, sys: 1.6 s, total: 11.7 s
# Wall time: 33.2 s

# %%
## Download Subsetted Data as CSV

# This cell downloads the filtered dataset as a ZIP-compressed CSV file.  
# The CSV includes metadata at the top as commented lines, and a `FileLink` object is returned to allow downloading directly from the notebook.


df.aodn.download_as_csv()
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/aodn_metadata-uuid_9fdb1eee-bc28-43a9-88c5-972324784837_mooring_southern_ocean_surface_properties_realtime_qc_data-hash_6c08dcee.csv.zip

# %% [markdown]
# ## Create a TIME and scalar/number filter
#
# This cell filters the dataset by time range and a scalar value (from a Parquet partition) using the `scalar_filter` argument.
# This leverages Parquet partitioning to apply efficient, server-side filtering, which significantly speeds up data loading.

# %%
# %%time
df = aodn_dataset.get_data(
                           scalar_filter={'deployment_number': 1}
                           )

df.info()
# Out:
# 2025-10-29 14:36:16,137 - aodn.GetAodn - INFO - Retrieving metadata for imos-data-lab-optimised/mooring_southern_ocean_surface_properties_realtime_qc.parquet
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231280 entries, 0 to 231279
# Data columns (total 74 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   TIME                           231280 non-null  datetime64[ns]
#  1   LATITUDE                       231280 non-null  float32
#  2   LONGITUDE                      231280 non-null  float32
#  3   UWND                           225560 non-null  float32
#  4   UWND_2                         218680 non-null  float32
#  5   VWND                           225560 non-null  float32
#  6   VWND_2                         218680 non-null  float32
#  7   WDIR                           231280 non-null  float32
#  8   WDIR_2                         218680 non-null  float32
#  9   WSPD                           225560 non-null  float32
#  10  WSPD_2                         218680 non-null  float32
#  11  ATMP                           225560 non-null  float32
#  12  ATMP_2                         218680 non-null  float32
#  13  AIRT                           225560 non-null  float32
#  14  AIRT_2                         218680 non-null  float32
#  15  RELH                           225560 non-null  float32
#  16  RELH_2                         218680 non-null  float32
#  17  TEMP                           225560 non-null  float32
#  18  TEMP_2                         218680 non-null  float32
#  19  CNDC                           225560 non-null  float32
#  20  CNDC_2                         218680 non-null  float32
#  21  PSAL                           225560 non-null  float32
#  22  PSAL_2                         218680 non-null  float32
#  23  RAIN_AMOUNT                    225560 non-null  float32
#  24  RAIN_AMOUNT_2                  218680 non-null  float32
#  25  SW                             225560 non-null  float32
#  26  SW_2                           218680 non-null  float32
#  27  LW                             225560 non-null  float32
#  28  LW_2                           231280 non-null  float32
#  29  PL_CMP                         225560 non-null  float32
#  30  PL_CMP2                        231280 non-null  float32
#  31  history                        231280 non-null  object
#  32  TIME_quality_control           231280 non-null  object
#  33  LATITUDE_quality_control       231280 non-null  object
#  34  LONGITUDE_quality_control      231280 non-null  object
#  35  UWND_quality_control           231280 non-null  object
#  36  UWND_2_quality_control         231280 non-null  object
#  37  VWND_quality_control           231280 non-null  object
#  38  VWND_2_quality_control         231280 non-null  object
#  39  WDIR_quality_control           231280 non-null  object
#  40  WDIR_2_quality_control         231280 non-null  object
#  41  WSPD_quality_control           231280 non-null  object
#  42  WSPD_2_quality_control         231280 non-null  object
#  43  ATMP_quality_control           231280 non-null  object
#  44  ATMP_2_quality_control         231280 non-null  object
#  45  AIRT_quality_control           231280 non-null  object
#  46  AIRT_2_quality_control         231280 non-null  object
#  47  RELH_quality_control           231280 non-null  object
#  48  RELH_2_quality_control         231280 non-null  object
#  49  TEMP_quality_control           231280 non-null  object
#  50  TEMP_2_quality_control         231280 non-null  object
#  51  CNDC_quality_control           231280 non-null  object
#  52  CNDC_2_quality_control         231280 non-null  object
#  53  PSAL_quality_control           231280 non-null  object
#  54  PSAL_2_quality_control         231280 non-null  object
#  55  RAIN_AMOUNT_quality_control    231280 non-null  object
#  56  RAIN_AMOUNT_2_quality_control  231280 non-null  object
#  57  SW_quality_control             231280 non-null  object
#  58  SW_2_quality_control           231280 non-null  object
#  59  LW_quality_control             231280 non-null  object
#  60  LW_2_quality_control           231280 non-null  object
#  61  PL_CMP_quality_control         231280 non-null  object
#  62  PL_CMP2_quality_control        231280 non-null  object
#  63  filename                       231280 non-null  object
#  64  WSPD_3                         39620 non-null   float32
#  65  WSPD_4                         32700 non-null   float32
#  66  WSPD_3_quality_control         41460 non-null   object
#  67  WSPD_4_quality_control         41460 non-null   object
#  68  RAD_SW2                        0 non-null       float32
#  69  RAD_LW                         0 non-null       float32
#  70  RAD_LW2                        0 non-null       float32
#  71  deployment_number              231280 non-null  int32
#  72  timestamp                      231280 non-null  int32
#  73  polygon                        231280 non-null  object
# dtypes: datetime64[ns](1), float32(35), int32(2), object(36)
# memory usage: 97.9+ MB
# CPU times: user 3.9 s, sys: 571 ms, total: 4.47 s
# Wall time: 9.02 s

# %%
df.sort_values('TIME').plot(y='TEMP', x='TIME', cmap='RdYlBu_r',
                            ylabel=f"{metadata['TEMP']['standard_name']} in {metadata['TEMP']['units']}" ,
                            title=metadata['global_attributes']['title']
                           )
# Out:
# <Axes: title={'center': 'IMOS - Deep Water Moorings - Southern Ocean Flux Station (SOFS) - Surface properties (real-time)'}, xlabel='TIME', ylabel='sea_surface_temperature in celsius'>
