# %% [markdown]
# ## Access Satellite Nanoplankton Fraction Oc3 1Day Aqua data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_nanoplankton_fraction_oc3_1day_aqua dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/9fde091c-9d38-4b2f-ba23-c262c21a41a2).

# %%
dataset_name = "satellite_nanoplankton_fraction_oc3_1day_aqua"

# %%
import xarray as xr
import fsspec

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
# only run once, then restart session if needed
# !pip install uv

import os
import sys

def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

# Get the current directory of the notebook
current_dir = os.getcwd()

# Check if requirements.txt exists in the current directory
local_requirements = os.path.join(current_dir, 'requirements.txt')
if os.path.exists(local_requirements):
    requirements_path = local_requirements
else:
    # Fall back to the online requirements.txt file
    requirements_path = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/requirements.txt'

# Install packages using uv and the determined requirements file
if is_colab():
    os.system(f'uv pip install --system -r {requirements_path}')
else:
    os.system('uv venv')
    os.system(f'uv pip install -r {requirements_path}')
# Out:
# ...
# Using CPython 3.12.6 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Audited 230 packages in 29ms

# %%
import requests
import os
if not os.path.exists('parquet_queries.py'):
  print('Downloading parquet_queries.py')
  url = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/aodn_cloud_optimised/lib/ParquetDataQuery.py'
  response = requests.get(url)
  with open('parquet_queries.py', 'w') as f:
      f.write(response.text)

# %%
from parquet_queries import plot_gridded_variable, create_timeseries, plot_time_coverage

# %%
# remote zarr dataset
url = f's3://aodn-cloud-optimised/{dataset_name}.zarr/'
ds = xr.open_zarr(fsspec.get_mapper(url, anon=True), consolidated=True)
ds
# Out:
# <xarray.Dataset> Size: 1TB
# Dimensions:             (latitude: 7001, longitude: 10001, time: 2000)
# Coordinates:
#   * latitude            (latitude) float64 56kB 10.0 9.99 9.98 ... -59.99 -60.0
#   * longitude           (longitude) float64 80kB 80.0 80.01 ... 180.0 180.0
#   * time                (time) datetime64[ns] 16kB 2002-07-04T05:30:00 ... 20...
# Data variables:
#     nanop_brewin2012in  (time, latitude, longitude) float64 1TB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      File initialised at 2020-08-07T05:37:45.976399\nInitialised...
#     source_path:  imos-srs/archive/oc/aqua/1d/v201909/2007/09/A20070925.L2OC_...

# %% [markdown]
# ## Plot time coverage

# %%
plot_time_coverage(ds)

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = create_timeseries(ds, 'nanop_brewin2012in', lat=-33, lon=130, start_time='2002-08-01', end_time='2004-02-20', lon_name="longitude", lat_name="latitude")
# Out:
# CPU times: user 3.89 s, sys: 538 ms, total: 4.43 s
# Wall time: 9.98 s
# /home/lbesnard/miniforge3/envs/AodnCloudOptimised/lib/python3.12/site-packages/dask/array/reductions.py:621: RuntimeWarning: All-NaN slice encountered
#   return np.nanmin(x_chunk, axis=axis, keepdims=keepdims)

# %% [markdown]
# ## Plot a gridded variable

# %%
plot_gridded_variable(ds, start_date='2002-08-01', lon_slice=(120, 150), lat_slice=(-50, -30), var_name='nanop_brewin2012in', n_days=3, coastline_resolution="50m", lon_name="longitude", lat_name="latitude", log_scale=True)
# Out:
# Nearest date in dataset: <xarray.DataArray 'time' ()> Size: 8B
# array('2002-07-29T05:30:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2002-07-29T05:30:00
# Attributes:
#     axis:           T
#     long_name:      time
#     standard_name:  time
# Variable Long Name: Nanoplankton fraction
# Method: Brewin et al (2012), Deep Sea Research II, 77-80, 117-127
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/parquet_queries.py:679: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
