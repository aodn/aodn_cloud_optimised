# %% [markdown]
# ## Access Satellite GHRSST L3S 1Day day time Single Sensor Australia (Zarr)
# This Jupyter notebook demonstrates how to access and plot satellite_ghrsst_l3s_1day_daytime_single_sensor_australia data, available as a [Zarr](https://zarr.dev/) dataset stored on S3.
#
# 🔗 More information about the dataset is available [in the AODN metadata catalogue](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/8bd3fe33-fd98-4307-ad23-424ad9a2907b).
#
# 📌 The source of truth for this notebook is maintained on [GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/satellite_ghrsst_l3s_1day_daytime_single_sensor_australia.ipynb).

# %%
dataset_name = "satellite_ghrsst_l3s_1day_daytime_single_sensor_australia"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()
# Out:
# Using CPython 3.12.11 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python3
# Creating virtual environment at: .venv
# ...
# Activate with: source .venv/bin/activate
# Using Python 3.12.11 environment at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised
# Resolved 241 packages in 66ms
# Audited 241 packages in 2ms
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:3445: UserWarning: registration of accessor <class 'DataQuery.AODNAccessor'> under name 'aodn' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("aodn")
# ✅ Local version 0.3.2 is up to date (remote: 0.3.2)

# %%
from DataQuery import GetAodn
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:3445: UserWarning: registration of accessor <class 'DataQuery.AODNAccessor'> under name 'aodn' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("aodn")

# %% [markdown]
# # Understanding the Dataset

# %%
# remote zarr dataset
aodn = GetAodn()
dname = f'{dataset_name}.zarr'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 426 ms, sys: 13.3 ms, total: 440 ms
# Wall time: 1.65 s

# %%
ds = aodn_dataset.zarr_store
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 11782 ;
# 	lat = 4500 ;
# 	lon = 6000 ;
#
# variables:
# 	float32 dt_analysis(time, lat, lon) ;
# 		dt_analysis:comment = The difference between this SST and the previous day's SST ;
# 		dt_analysis:long_name = deviation from last SST analysis ;
# 		dt_analysis:source = NCDC-L4LRblend-GLOB-AVHRR_OI ;
# 		dt_analysis:units = kelvin ;
# 		dt_analysis:valid_max = 127 ;
# 		dt_analysis:valid_min = -127 ;
# 	object filename(time) ;
# 	float32 l2p_flags(time, lat, lon) ;
# ...

# %% [markdown]
# ## Plot time coverage

# %%
aodn_dataset.get_temporal_extent()
# Out:
# (Timestamp('1992-03-21 03:20:00'), Timestamp('2025-06-06 03:20:00'))

# %%
aodn_dataset.plot_time_coverage()

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = aodn_dataset.get_timeseries_data(var_name='sea_surface_temperature', 
                                                  lat=-40, 
                                                  lon=130, 
                                                  date_start='1992-04-02', 
                                                  date_end='2025-03-31', 
                                                  lon_name_override="lon", 
                                                  lat_name_override="lat").plot_timeseries()
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:1469: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled = df[self.var_name].resample(resample)
# CPU times: user 28 s, sys: 4.43 s, total: 32.4 s
# Wall time: 2min 9s

# %%
# %%time
time_series_df = aodn_dataset.get_timeseries_data(var_name='sea_surface_temperature', 
                                                  lat=-40, 
                                                  lon=130, 
                                                  date_start='2018-04-02', 
                                                  date_end='2019-07-31', 
                                                  lon_name_override="lon", 
                                                  lat_name_override="lat").plot_timeseries()
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:1469: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled = df[self.var_name].resample(resample)
# CPU times: user 967 ms, sys: 204 ms, total: 1.17 s
# Wall time: 2.97 s

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
time_series_df = aodn_dataset.plot_gridded_variable(var_name='sea_surface_temperature', 
                                                    date_start='2005-10-01',                                                
                                                    lon_name_override="lon", 
                                                    lat_name_override="lat", 
                                                    lon_slice=(146, 150), 
                                                    lat_slice=(-44, -41), 
                                                    n_days=30, 
                                                    coastline_resolution="50m", 
                                                    log_scale=False)
# Out:
# 2025-12-23 14:49:18,168 - aodn.GetAodn - INFO - Plotting 'sea surface skin temperature' for 1 time steps.
# 2025-12-23 14:49:18,229 - aodn.GetAodn - WARNING - No valid data found across all selected dates and coordinates to determine color scale.
# CPU times: user 36 ms, sys: 758 µs, total: 36.7 ms
# Wall time: 68.8 ms

# %%
aodn_dataset.plot_gridded_variable_viewer_calendar(
    var_name="sea_surface_temperature",
    lon_slice=(145,149),
    lat_slice=(-44,-41),
    coastline_resolution="50m", 
    n_days=31,
)
