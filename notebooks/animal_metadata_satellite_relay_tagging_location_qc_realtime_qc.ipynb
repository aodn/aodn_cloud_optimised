# %% [markdown]
# ## Access Animal Satellite Relay Tagging Metadata Realtime QC (Parquet)
# This Jupyter notebook demonstrates how to access and plot animal_metadata_satellite_relay_tagging_location_qc_realtime_qc data, available as a [Parquet](https://parquet.apache.org) dataset stored on S3.
#
# 🔗 More information about the dataset is available [in the AODN metadata catalogue](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/b2548767-514f-4a31-b65e-36bb894382d5).
#
# 📌 The source of truth for this notebook is maintained on [GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/animal_metadata_satellite_relay_tagging_location_qc_realtime_qc.ipynb).

# %%
dataset_name = "animal_metadata_satellite_relay_tagging_location_qc_realtime_qc"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()
# Out:
# ✅ Virtual environment already exists, skipping creation.
# Using Python 3.12.6 environment at: /home/lbesnard/github_repo/aodn_cloud_optimised/.venv
# Resolved 201 packages in 60ms
# Checked 201 packages in 1ms
# ✅ Local version 0.3.23 is up to date (remote: 0.3.18)

# %%
from DataQuery import GetAodn
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:4676: UserWarning: registration of accessor <class 'DataQuery.AODNAccessor'> under name 'aodn' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("aodn")

# %% [markdown]
# # Understanding the Dataset

# %% [markdown]
# ## Understanding Parquet Partitioning
#
# Parquet files can be **partitioned** by one or more columns, which means the data is physically organised into folders based on the values in those columns. This is similar to how databases use indexes to optimise query performance.
#
# Partitioning enables **faster filtering**: when you query data using a partitioned column, only the relevant subset of files needs to be read—improving performance significantly.
#
# For example, if a dataset is partitioned by `"site_code"`, `"timestamp"`, and `"polygon"`, filtering on `"site_code"` allows the system to skip unrelated files entirely.
#
# In this notebook, the `GetAodn` class includes built-in methods to efficiently filter data by **time** and **latitude/longitude** using the **timestamp** and **polygon** partitions. Other partitions can be used for filtering via the `scalar_filter`.
#
# Any filtering on columns that are **not** partitioned can be significantly slower, as all files may need to be scanned. However, the `GetAodn` class provides a `scalar_filter` method that lets you apply these filters at load time—before the data is fully read—helping reduce the size of the resulting DataFrame.
#
# Once the dataset is loaded, further filtering using Pandas is efficient and flexible.
#
# See further below in the notebook for examples of how to filter the data effectively.
#
# To view the actual partition columns for this dataset, run:

# %%
aodn = GetAodn()
dname = f'{dataset_name}.parquet'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 6.91 ms, sys: 1.3 ms, total: 8.21 ms
# Wall time: 7.66 ms

# %%
aodn_dataset.dataset.partitioning.schema
# Out:
# timestamp: int32
# polygon: string

# %% [markdown]
# ## List unique partition values

# %%
# %%time
unique_partition_value = aodn_dataset.get_unique_partition_values('YOUR_PARTITION_KEY')
print(list(unique_partition_value)[0:2])  # showing a subset only
# Out:
# []
# CPU times: user 622 µs, sys: 0 ns, total: 622 µs
# Wall time: 596 µs

# %% [markdown]
# ## Visualise Spatial Extent of the dataset
# This section plots the polygons representing the areas where data is available. It helps to identify and create a bounding box around the regions containing data.

# %%
aodn_dataset.plot_spatial_extent()
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/.venv/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:143: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## Get Temporal Extent of the dataset

# %% [markdown]
# Similary to the spatial extent, we're retrieving the minimum and maximum timestamp partition values of the dataset. This is not necessarely accurately representative of the TIME values, as the timestamp partition can be yearly/monthly... but is here to give an idea

# %%
# %%time
aodn_dataset.get_temporal_extent()
# Out:
# CPU times: user 42 ms, sys: 48.1 ms, total: 90 ms
# Wall time: 169 ms
# (Timestamp('2025-12-31 16:00:00'), Timestamp('2026-05-28 03:00:00'))

# %% [markdown]
# ## Read Metadata
#
# For all Parquet datasets, we create a sidecar file named **_common_metadata** in the root of the dataset. This file contains both the dataset-level and variable-level attributes.
# The metadata can be retrieved below as a dictionary, and it will also be included in the pandas DataFrame when using the `get_data` method from the `GetAodn` class.

# %%
metadata = aodn_dataset.get_metadata()
metadata
# Out:
# 2026-06-03 13:05:40,348 - aodn.GetAodn - INFO - Retrieving metadata for aodn-cloud-optimised/animal_metadata_satellite_relay_tagging_realtime_qc.parquet
# {'sattag_program': {'type': 'string'},
#  'device_id': {'type': 'string'},
#  'ptt': {'type': 'int32'},
#  'body': {'type': 'int32'},
#  'device_wmo_ref': {'type': 'string'},
#  'tag_type': {'type': 'string'},
#  'common_name': {'type': 'string'},
#  'species': {'type': 'string'},
#  'release_longitude': {'type': 'double'},
#  'release_latitude': {'type': 'double'},
#  'release_site': {'type': 'string'},
#  'release_date': {'type': 'timestamp[ns]'},
#  'recovery_date': {'type': 'string'},
#  'age_class': {'type': 'string'},
#  'sex': {'type': 'string'},
#  'length': {'type': 'double'},
#  'estimated_mass': {'type': 'double'},
#  'actual_mass': {'type': 'double'},
#  'state_country': {'type': 'string'},
#  'qc_start_date': {'type': 'timestamp[ns]'},
#  'qc_end_date': {'type': 'timestamp[ns]'},
#  'qc_method': {'type': 'string'},
#  'qc_method_version': {'type': 'string'},
#  'qc_proj4string': {'type': 'string'},
#  'qc_run_date': {'type': 'string'},
#  'filename': {'type': 'string',
#   'units': '1',
#   'long_name': 'Filename of the source file'},
#  'timestamp': {'type': 'int64',
#   'units': '1',
#   'long_name': 'Partition timestamp'},
#  'polygon': {'type': 'string',
#   'units': '1',
#   'long_name': 'Spatial partition polygon'},
#  'global_attributes': {'metadata_uuid': 'b2548767-514f-4a31-b65e-36bb894382d5',
#   'dataset_name': 'animal_metadata_satellite_relay_tagging_realtime_qc'}}

# %% [markdown]
# # Data Query and Plot

# %% [markdown]
# ## Create a TIME and BoundingBox filter
#
# This cell loads a subset of the dataset based on a time range and a spatial bounding box. The result is returned as a pandas DataFrame, and basic information about its structure is displayed.

# %%
# %%time
# NRT dataset, so we re just showing how to do a time filtering here taking the whole data
df = aodn_dataset.get_data(date_start=aodn_dataset.get_temporal_extent()[0].strftime('%Y-%m-%d'), 
                           date_end=aodn_dataset.get_temporal_extent()[1].strftime('%Y-%m-%d'),
                           )

df.info()
# Out:
# 2026-06-03 13:05:40,910 - aodn.GetAodn - INFO - Retrieving metadata for aodn-cloud-optimised/animal_metadata_satellite_relay_tagging_realtime_qc.parquet
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sattag_program     53 non-null     object
#  1   device_id          53 non-null     object
#  2   ptt                53 non-null     int32
#  3   body               53 non-null     int32
#  4   device_wmo_ref     53 non-null     object
#  5   tag_type           53 non-null     object
#  6   common_name        53 non-null     object
#  7   species            53 non-null     object
#  8   release_longitude  53 non-null     float64
#  9   release_latitude   53 non-null     float64
#  10  release_site       53 non-null     object
#  11  release_date       53 non-null     datetime64[ns]
#  12  recovery_date      0 non-null      object
#  13  age_class          0 non-null      object
#  14  sex                0 non-null      object
#  15  length             0 non-null      float64
#  16  estimated_mass     0 non-null      float64
#  17  actual_mass        0 non-null      float64
#  18  state_country      53 non-null     object
#  19  qc_start_date      53 non-null     datetime64[ns]
#  20  qc_end_date        53 non-null     datetime64[ns]
#  21  qc_method          53 non-null     object
#  22  qc_method_version  53 non-null     object
#  23  qc_proj4string     53 non-null     object
#  24  qc_run_date        53 non-null     object
#  25  filename           53 non-null     object
#  26  timestamp          53 non-null     int32
#  27  polygon            53 non-null     object
# dtypes: datetime64[ns](3), float64(5), int32(3), object(17)
# memory usage: 11.1+ KB
# CPU times: user 51 ms, sys: 8.7 ms, total: 59.7 ms
# Wall time: 460 ms

# %%
df
# Out:
#    sattag_program          device_id     ptt   body device_wmo_ref  \
# 0           ct189       ct189-585-25   35405  20585       Q9902306
# 1           ct189       ct189-593-25   35413  20593       Q9902314
# 2           ct190      ct190-F999-24  265909  15999       Q9902295
# 3           ct190       ct190-976-24  265888  15976       Q9902286
# 4           ct189       ct189-576-25   35395  20576       Q9902297
# 5           ct189       ct189-588-25   35408  20588       Q9902309
# 6           ct190  ct190-266-BAT2-20  204698  15266       Q9902280
# 7           ct189       ct189-580-25   35399  20580       Q9902301
# 8           ct190       ct190-979-24  265903  15979       Q9902289
# 9           ct190       ct190-962-24  265901  15962       Q9902283
# 10          ct190      ct190-F996-24  265908  15996       Q9902293
# 11          ct189       ct189-586-25   35406  20586       Q9902307
# 12          ct190       ct190-994-24  265891  15994       Q9902291
# 13          ct190       ct190-978-24  265896  15978       Q9902288
# 14          ct189       ct189-591-25   35411  20591       Q9902312
# 15          ct190       ct190-897-24  265900  15897       Q9902282
# 16          ct190      ct190-F988-24  265906  15988       Q9902290
# 17          ct189       ct189-587-25   35407  20587       Q9902308
# 18          ct190       ct190-975-24  265895  15975       Q9902285
# 19          ct190      ct190-F995-24  265907  15995       Q9902292
# 20          ct189       ct189-596-25   35416  20596       Q9902317
# 21          ct189       ct189-594-25   35414  20594       Q9902315
# 22          ct189       ct189-592-25   35412  20592       Q9902313
+proj=stere +lat_0=-90 +lat_ts=-71 +lon_0=100 ...  2026-06-01T13:05:15Z
# 32  +proj=stere +lat_0=-90 +lat_ts=-71 +lon_0=100 ...  2026-06-01T13:05:15Z
# 33         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 34         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 35         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 36         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 37         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 38         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 39         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 40         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 41         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 42         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 43         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 44         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 45         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 46         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 47         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 48         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 49         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 50         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 51         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
# 52         +proj=merc +ellps=WGS84 +units=km +no_defs  2026-06-01T12:33:02Z
#
#                                              filename   timestamp  \
# 0   IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1764547200
# 1   IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1764547200
# 2   IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1764547200
# 3   IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1764547200
# 4   IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1764547200
# 5   IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 6   IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1764547200
# 7   IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1764547200
# 8   IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 9   IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 10  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 11  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1764547200
# 12  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 13  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 14  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 15  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 16  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 17  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 18  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 19  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 20  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 21  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 22  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 23  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 24  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1767225600
# 25  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 26  IMOS_ATF-SATTAG_Location-QC_metadata_ct190_nrt...  1769904000
# 27  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 28  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 29  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 30  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 31  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 32  IMOS_ATF-SATTAG_Location-QC_metadata_ct189_nrt...  1767225600
# 33  IMOS_ATF-SATTAG_Location-QC_metadata_tu126_nrt...  1777593600