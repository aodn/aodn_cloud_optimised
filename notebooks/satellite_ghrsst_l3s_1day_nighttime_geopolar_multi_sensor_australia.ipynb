# %% [markdown]
# ## Access Satellite Ghrsst L3S 1Day Nighttime Geopolar Multi Sensor Australia data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_ghrsst_l3s_1day_nighttime_geopolar_multi_sensor_australia dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/7d8d046b-6002-4897-b781-04e7324d6af8).

# %%
dataset_name = "satellite_ghrsst_l3s_1day_nighttime_geopolar_multi_sensor_australia"

# %%
import xarray as xr
import fsspec

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
# only run once, then restart session if needed
# !pip install uv

import os
import sys

def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

# Get the current directory of the notebook
current_dir = os.getcwd()

# Check if requirements.txt exists in the current directory
local_requirements = os.path.join(current_dir, 'requirements.txt')
if os.path.exists(local_requirements):
    requirements_path = local_requirements
else:
    # Fall back to the online requirements.txt file
    requirements_path = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/requirements.txt'

# Install packages using uv and the determined requirements file
if is_colab():
    xr.set_options(display_style='text')
    os.system(f'uv pip install --system -r {requirements_path}')
else:
    os.system('uv venv')
    os.system(f'uv pip install -r {requirements_path}')
# Out:
# Requirement already satisfied: uv in /home/lbesnard/miniforge3/envs/AodnCloudOptimised/lib/python3.12/site-packages (0.4.18)
# Using CPython 3.12.6 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Audited 234 packages in 39ms

# %%
import requests
import os
if not os.path.exists('DataQuery.py'):
  print('Downloading DataQuery.py')
  url = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/aodn_cloud_optimised/lib/DataQuery.py'
  response = requests.get(url)
  with open('DataQuery.py', 'w') as f:
      f.write(response.text)

# %%
from DataQuery import plot_gridded_variable, create_timeseries, plot_time_coverage

# %%
# remote zarr dataset
url = f's3://aodn-cloud-optimised/{dataset_name}.zarr/'
ds = xr.open_zarr(fsspec.get_mapper(url, anon=True), chunks=None, consolidated=True)
ds
# Out:
# <xarray.Dataset> Size: 8TB
# Dimensions:                          (time: 2196, lat: 4500, lon: 6000)
# Coordinates:
#   * lat                              (lat) float32 18kB 19.99 19.97 ... -69.99
#   * lon                              (lon) float32 24kB 70.01 70.03 ... 190.0
#   * time                             (time) datetime64[ns] 18kB 2015-09-01T15...
# Data variables: (12/17)
#     aerosol_dynamic_indicator        (time, lat, lon) float64 474GB ...
#     dt_analysis                      (time, lat, lon) float64 474GB ...
#     filename                         (time) <U72 632kB ...
#     l2p_flags                        (time, lat, lon) float64 474GB ...
#     quality_level                    (time, lat, lon) float64 474GB ...
#     satellite_zenith_angle           (time, lat, lon) float64 474GB ...
#     ...                               ...
#     sses_standard_deviation          (time, lat, lon) float64 474GB ...
#     sst_count                        (time, lat, lon) float64 474GB ...
#     sst_dtime                        (time, lat, lon) float64 474GB ...
#     sst_mean                         (time, lat, lon) float64 474GB ...
#     sst_standard_deviation           (time, lat, lon) float64 474GB ...
#     wind_speed                       (time, lat, lon) float64 474GB ...
# Attributes: (12/47)
#     Conventions:                CF-1.6
#     Metadata_Conventions:       Unidata Dataset Discovery v1.0
#     Metadata_Link:              TBA
#     acknowledgment:             Any use of these data requires the following ...
#     cdm_data_type:              grid
#     comment:                    Geo-Polar Multi-sensor L3S retrievals produce...
#     ...                         ...
#     summary:                    Skin sea surface temperature retrievals from ...
#     time_coverage_end:          20210511T033611Z
#     time_coverage_start:        20210510T032614Z
#     title:                      IMOS L3S Nighttime gridded geo-polar multiple...
#     uuid:                       4e37984b-bf88-47cf-ba8b-0814977f41e5
#     westernmost_longitude:      70.01000213623047

# %% [markdown]
# ## Plot time coverage

# %%
# %%time
plot_time_coverage(ds)
# Out:
# CPU times: user 189 ms, sys: 473 ms, total: 662 ms
# Wall time: 83.5 ms

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = create_timeseries(ds, 'sea_surface_temperature', lat=-40, lon=130, start_time='2015-12-01', end_time='2016-12-31')
# Out:
# CPU times: user 3.6 s, sys: 1.07 s, total: 4.67 s
# Wall time: 19.2 s

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
plot_gridded_variable(ds, start_date='2016-06-01', lon_slice=(120, 150), lat_slice=(-50, -30), var_name='sea_surface_temperature', n_days=6, coastline_resolution="50m")
# Out:
# Nearest date in dataset: <xarray.DataArray 'time' ()> Size: 8B
# array('2016-05-31T15:20:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2016-05-31T15:20:00
# Attributes:
#     axis:           T
#     comment:        A typical reference time for data
#     long_name:      reference time of sst file
#     standard_name:  time
# Variable Long Name: sea surface skin temperature
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:880: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# CPU times: user 7 s, sys: 4.86 s, total: 11.9 s
# Wall time: 22.8 s
