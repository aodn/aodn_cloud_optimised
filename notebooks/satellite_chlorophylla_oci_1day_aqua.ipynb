# %% [markdown]
# ## Access Satellite Chlorophyll-a OCI 1Day Aqua data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_chlorophylla_oci_1day_aqua dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/24055e3a-94e5-40bb-b97f-7519f0482d6a).
#
# 📌 The point of truth for this notebook is [on GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/satellite_chlorophylla_oci_1day_aqua.ipynb).

# %%
dataset_name = "satellite_chlorophylla_oci_1day_aqua"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()
# Out:
# Using CPython 3.12.11 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Using Python 3.12.11 environment at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised
# Audited 256 packages in 39ms
# ✅ Local version 0.2.4 is up to date (remote: 0.2.4)

# %%
from DataQuery import GetAodn
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:2989: UserWarning: registration of accessor <class 'DataQuery.AODNAccessor'> under name 'aodn' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("aodn")

# %% [markdown]
# # Understanding the Dataset

# %%
aodn = GetAodn()
dname = f'{dataset_name}.zarr'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 687 ms, sys: 80.5 ms, total: 768 ms
# Wall time: 2.96 s

# %%
ds = aodn_dataset.zarr_store
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 8033 ;
# 	latitude = 7001 ;
# 	longitude = 10001 ;
#
# variables:
# 	float64 chl_oci(time, latitude, longitude) ;
# 		chl_oci:flag_applied = HISATZEN LAND CLDICE NAVFAIL ;
# 		chl_oci:long_name = Chlorophyll Concentration, OCI Algorithm ;
# 		chl_oci:units = mg/m^3 ;
# 	float64 l2_flags(time, latitude, longitude) ;
# 		l2_flags:flag_applied = HISATZEN LAND CLDICE NAVFAIL ;
# 		l2_flags:flag_masks = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912, 1073741824, -2147483648] ;
# 		l2_flags:flag_meanings = ATMFAIL LAND PRODWARN HIGLINT HILT HISATZEN COASTZ SPARE STRAYLIGHT CLDICE COCCOLITH TURBIDW HISOLZEN SPARE LOWLW CHLFAIL NAVWARN ABSAER SPARE MAXAERITER MODGLINT CHLWARN ATMWARN SPARE SEAICE NAVFAIL FILTER SPARE SPARE HIPOL PRODFAIL SPARE ;
# 		l2_flags:long_name = Level-2 Processing Flags ;
# 		l2_flags:units = 1 ;
# 	float64 latitude(latitude) ;
# 		latitude:axis = Y ;
# 		latitude:long_name = latitude ;
# 		latitude:standard_name = latitude ;
# 		latitude:units = degrees_north ;
# 	float64 longitude(longitude) ;
# 		longitude:axis = X ;
# 		longitude:long_name = longitude ;
# 		longitude:standard_name = longitude ;
# 		longitude:units = degrees_east ;
# 	datetime64[ns] time(time) ;
# 		time:axis = T ;
# 		time:long_name = time ;
# 		time:standard_name = time ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:NCO = netCDF Operators version 5.0.6 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco) ;
# 	:history = Tue Sep 10 16:24:01 2024: ncks -A -v l2_flags -o A20240908.L2OC_BASE.aust.chl_oci.nc A20240908.L2OC_BASE.aust.l2_flags.nc
# File initialised at 2024-09-10T06:21:10.179322
# Initialised var chl_oci at 2024-09-10T06:21:10.429626
# Add Granule A20240908_0355.20240909201008.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:17.785573
# Add Granule A20240908_0400.20240909201008.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:18.588710
# Add Granule A20240908_0405.20240909201008.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:19.214634
# Add Granule A20240908_0410.20240909201552.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:19.788392
# Add Granule A20240908_0530.20240909201727.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:20.352375
# Add Granule A20240908_0535.20240909201744.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:21.587855
# Add Granule A20240908_0540.20240909202009.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:22.576444
# Add Granule A20240908_0545.20240909202136.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:23.228004
# Add Granule A20240908_0550.20240909202253.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:24.057706
# Add Granule A20240908_0715.20240909202414.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:24.647770
# Add Granule A20240908_0720.20240909202713.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:25.518976
# Add Granule A20240908_0725.20240909202840.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:26.093216
# Add Granule A20240908_0730.20240909202848.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:26.833577
# Add Granule A20240908_0855.20240909203226.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:27.550551
# Add Granule A20240908_0900.20240909203347.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:28.330655
# Add Granule A20240908_0905.20240909203448.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:28.866141
# Add Granule A20240908_0910.20240909203742.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:29.523617
# Add Granule A20240908_1030.20240909204015.L2OC_BASE.chl_oci.nc at 2024-09-10T06:21:29.920705 ;
# 	:history_of_appended_files = Tue Sep 10 16:24:01 2024: Appended file A20240908.L2OC_BASE.aust.l2_flags.nc had following "history" attribute:
# File initialised at 2024-09-10T06:21:10.179322
# Initialised var l2_flags at 2024-09-10T06:23:32.668841
# Add Granule A20240908_0355.20240909201008.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:33.924994
# Add Granule A20240908_0400.20240909201008.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:34.171461
# Add Granule A20240908_0405.20240909201008.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:34.364354
# Add Granule A20240908_0410.20240909201552.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:34.498891
# Add Granule A20240908_0530.20240909201727.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:34.681644
# Add Granule A20240908_0535.20240909201744.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:34.946642
# Add Granule A20240908_0540.20240909202009.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:35.209240
# Add Granule A20240908_0545.20240909202136.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:35.356865
# Add Granule A20240908_0550.20240909202253.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:35.489345
# Add Granule A20240908_0715.20240909202414.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:35.731277
# Add Granule A20240908_0720.20240909202713.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:35.940471
# Add Granule A20240908_0725.20240909202840.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:36.107552
# Add Granule A20240908_0730.20240909202848.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:36.212833
# Add Granule A20240908_0855.20240909203226.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:36.373143
# Add Granule A20240908_0900.20240909203347.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:36.521674
# Add Granule A20240908_0905.20240909203448.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:36.600961
# Add Granule A20240908_0910.20240909203742.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:36.630903
# Add Granule A20240908_1030.20240909204015.L2OC_BASE.l2_flags.nc at 2024-09-10T06:23:36.707070
#  ;
# 	:source_path = imos-srs/archive/oc/aqua/v202302/1d/2024/09/A20240908.L2OC_BASE.aust.chl_oci.nc ;
# }

# %% [markdown]
# ## Plot time coverage

# %%
aodn_dataset.get_temporal_extent()
# Out:
# (Timestamp('2002-07-04 05:30:00'), Timestamp('2024-12-06 05:30:00'))

# %%
aodn_dataset.plot_time_coverage()

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = aodn_dataset.get_timeseries_data(var_name='chl_oci', 
                                                  lat=-48, 
                                                  lon=144, 
                                                  date_start='2010-01-01', 
                                                  date_end='2010-12-31', 
                                                  lon_name_override="longitude", 
                                                  lat_name_override="latitude")
# Out:
# CPU times: user 1.52 s, sys: 215 ms, total: 1.73 s
# Wall time: 4.45 s

# %%
# %%time
time_series_df = aodn_dataset.plot_timeseries(var_name='chl_oci', 
                                                  lat=-48, 
                                                  lon=144, 
                                                  date_start='2010-01-01', 
                                                  date_end='2010-12-31', 
                                                  lon_name_override="longitude", 
                                                  lat_name_override="latitude")
# Out:
# CPU times: user 949 ms, sys: 254 ms, total: 1.2 s
# Wall time: 3.66 s

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
time_series_df = aodn_dataset.plot_gridded_variable(var_name='chl_oci', 
                                                    date_start='2010-12-01', 
                                                    lon_name_override="longitude", 
                                                    lat_name_override="latitude", 
                                                    lon_slice=(140, 150),
                                                    lat_slice=(-50, -36),
                                                    n_days=6, 
                                                    coastline_resolution="50m", 
                                                    log_scale=True)
# Out:
# 2025-08-11 17:12:07,204 - aodn.GetAodn - INFO - Plotting 'Chlorophyll Concentration, OCI Algorithm' for 6 time steps.
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:2591: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(
# CPU times: user 6.6 s, sys: 4.07 s, total: 10.7 s
# Wall time: 9.48 s
