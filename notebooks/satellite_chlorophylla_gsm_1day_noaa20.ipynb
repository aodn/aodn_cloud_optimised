# %% [markdown]
# ## Access Satellite Net Primary Productivity GSM 1Day NOAA20 data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_chlorophylla_gsm_1day_noaa20 dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/ad4d6908-3a36-4991-996a-5b00ac162794).
#
# 📌 The point of truth for this notebook is [on GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/satellite_chlorophylla_gsm_1day_noaa20.ipynb).

# %%
dataset_name = "satellite_chlorophylla_gsm_1day_noaa20"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()
# Out:
# ✅ Virtual environment already exists, skipping creation.
# Using Python 3.12.11 environment at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised
# Resolved 241 packages in 76ms
# Audited 241 packages in 2ms
# ✅ Local version 0.3.8 is up to date (remote: 0.3.3)

# %%
from DataQuery import GetAodn
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:3529: UserWarning: registration of accessor <class 'DataQuery.AODNAccessor'> under name 'aodn' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("aodn")

# %% [markdown]
# # Understanding the Dataset

# %%
aodn = GetAodn()
dname = f'{dataset_name}.zarr'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 392 ms, sys: 47.2 ms, total: 439 ms
# Wall time: 1.54 s

# %%
ds = aodn_dataset.zarr_store
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 797 ;
# 	latitude = 9601 ;
# 	longitude = 13601 ;
#
# variables:
# 	float64 chl_gsm(time, latitude, longitude) ;
# 		chl_gsm:flag_applied = HISATZEN HIGLINT LAND CLDICE NAVFAIL ;
# 		chl_gsm:long_name = Chlorophyll Concentration, GSM model ;
# 		chl_gsm:units = mg/m^3 ;
# 	<U39 filename(time) ;
# 	float64 latitude(latitude) ;
# 		latitude:axis = Y ;
# 		latitude:long_name = latitude ;
# 		latitude:standard_name = latitude ;
# 		latitude:units = degrees_north ;
# 	float64 longitude(longitude) ;
# 		longitude:axis = X ;
# 		longitude:long_name = longitude ;
# 		longitude:standard_name = longitude ;
# 		longitude:units = degrees_east ;
# 	datetime64[ns] time(time) ;
# 		time:axis = T ;
# 		time:long_name = time ;
# 		time:standard_name = time ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:dataset_name = satellite_chlorophylla_gsm_1day_noaa20 ;
# 	:history = File initialised at 2025-01-26T19:25:05.776040
# ...

# %% [markdown]
# ## Plot time coverage

# %%
aodn_dataset.get_temporal_extent()
# Out:
# (Timestamp('2023-02-08 05:30:00'), Timestamp('2025-04-14 05:30:00'))

# %%
aodn_dataset.plot_time_coverage()

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = aodn_dataset.get_timeseries_data(var_name='chl_gsm', 
                                                  lat=-40, 
                                                  lon=130, 
                                                  date_start='2024-01-01', 
                                                  date_end='2024-10-31', 
                                                  lon_name_override="longitude", 
                                                  lat_name_override="latitude").plot_timeseries()
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:1619: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled = df[self.var_name].resample(resample)
# CPU times: user 2.92 s, sys: 570 ms, total: 3.49 s
# Wall time: 12.5 s

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
time_series_df = aodn_dataset.plot_gridded_variable(var_name='chl_gsm', 
                                                    date_start='2024-02-01', 
                                                    lon_name_override="longitude", 
                                                    lat_name_override="latitude", 
                                                    lon_slice=(140, 150),
                                                    lat_slice=(-50, -30),
                                                    n_days=6, 
                                                    coastline_resolution="110m", 
                                                    log_scale=True)
# Out:
# 2026-03-19 10:47:19,916 - aodn.GetAodn - INFO - Plotting 'Chlorophyll Concentration, GSM model' for 6 time steps.
# 2026-03-19 10:47:29,995 - aodn.GetAodn - WARNING - No valid data for 2024-02-02 05:30:00, skipping plot.
# 2026-03-19 10:47:30,787 - aodn.GetAodn - WARNING - No valid data for 2024-02-04 05:30:00, skipping plot.
# 2026-03-19 10:47:30,788 - aodn.GetAodn - WARNING - No valid data for 2024-02-05 05:30:00, skipping plot.
# 2026-03-19 10:47:30,788 - aodn.GetAodn - WARNING - No valid data for 2024-02-06 05:30:00, skipping plot.
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:2975: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(
# CPU times: user 8.28 s, sys: 2.12 s, total: 10.4 s
# Wall time: 15.7 s
