# %% [markdown]
# ## Access Radar Rottnest Shelf Velocity Hourly Averaged Delayed QC data in Zarr
# A jupyter notebook to show how to access and plot the AODN radar_RottnestShelf_velocity_hourly_averaged_delayed_qc dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/028b9801-279f-427c-964b-0ffcdf310b59).
#
# 📌 The point of truth for this notebook is [on GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/radar_RottnestShelf_velocity_hourly_averaged_delayed_qc.ipynb).

# %%
dataset_name = "radar_RottnestShelf_velocity_hourly_averaged_delayed_qc"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()
# Out:
# Using Python 3.12.6 environment at: /home/lbesnard/github_repo/aodn_cloud_optimised/.venv
# Resolved 155 packages in 51ms
# Checked 155 packages in 1ms
# ✅ Virtual environment already exists, skipping creation.
# ✅ Local version 0.3.11 is up to date (remote: 0.3.11)

# %%
from DataQuery import GetAodn
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:4002: UserWarning: registration of accessor <class 'DataQuery.AODNAccessor'> under name 'aodn' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("aodn")

# %% [markdown]
# # Understanding the Dataset

# %%
aodn = GetAodn()
dname = f'{dataset_name}.zarr'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 523 ms, sys: 37.1 ms, total: 560 ms
# Wall time: 1.27 s

# %%
ds = aodn_dataset.zarr_store
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	TIME = 81851 ;
# 	LATITUDE = 92 ;
# 	LONGITUDE = 62 ;
#
# variables:
# 	float64 GDOP(TIME, LATITUDE, LONGITUDE) ;
# 		GDOP:comment = This angle is used to assess the impact of Geometric Dilution of Precision. If angle >= 150 or <= 30, then QC flag will not be lower than 4 (see abstract). ;
# 		GDOP:long_name = radar beam intersection angle ;
# 		GDOP:units = Degrees ;
# 		GDOP:valid_max = 180.0 ;
# 		GDOP:valid_min = 0.0 ;
# 	float64 LATITUDE(LATITUDE) ;
# 		LATITUDE:axis = Y ;
# 		LATITUDE:long_name = latitude ;
# 		LATITUDE:reference_datum = geographical coordinates, WGS84 datum ;
# 		LATITUDE:standard_name = latitude ;
# 		LATITUDE:units = degrees_north ;
# 		LATITUDE:valid_max = 90.0 ;
# 		LATITUDE:valid_min = -90.0 ;
# 	float64 LONGITUDE(LONGITUDE) ;
# 		LONGITUDE:axis = X ;
# 		LONGITUDE:long_name = longitude ;
# 		LONGITUDE:reference_datum = geographical coordinates, WGS84 datum ;
# 		LONGITUDE:standard_name = longitude ;
# ...

# %% [markdown]
# ## Plot time coverage

# %%
aodn_dataset.get_temporal_extent()
# Out:
# (Timestamp('2010-02-23 06:30:00.000003072'),
#  Timestamp('2024-05-03 23:29:59.999996928'))

# %%
aodn_dataset.plot_time_coverage()

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
aodn_dataset.plot_radar_water_velocity_gridded(date_start='2014-02-22')
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:1144: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])  # Leave space for the colorbar
# /home/lbesnard/github_repo/aodn_cloud_optimised/.venv/lib/python3.12/site-packages/matplotlib/quiver.py:676: RuntimeWarning: Mean of empty slice.
#   amean = a[~self.Umask].mean()
# /home/lbesnard/github_repo/aodn_cloud_optimised/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/lbesnard/github_repo/aodn_cloud_optimised/.venv/lib/python3.12/site-packages/matplotlib/quiver.py:676: RuntimeWarning: Mean of empty slice.
#   amean = a[~self.Umask].mean()
# ...

# %%
subset = aodn_dataset.get_data(date_start='2014-02-22', date_end='2014-02-23')
valid_count = subset.UCUR.notnull().sum().values
print(f"Number of valid data points: {valid_count}")
# Out:
# Number of valid data points: 543

# %%
import matplotlib.pyplot as plt

# Select the first time step (index 0)
subset.UCUR.isel(TIME=0).plot(x='LONGITUDE', y='LATITUDE', cmap='RdBu_r')

plt.title(f"UCUR - {subset.TIME.values[0]}")
plt.show()

# %%
# %%time
aodn_dataset.plot_radar_water_velocity_rose(date_start='2018-04-02T00:00:00', 
                                            date_end='2018-04-03T00:00:00')
# Out:
# CPU times: user 195 ms, sys: 195 ms, total: 390 ms
# Wall time: 351 ms

# %%
# %%time
aodn_dataset.plot_radar_water_velocity_timeseries(date_start='2016-01-01T00:00:00', 
                                            date_end='2016-12-30T00:00:00')
# Out:
# Using highest-density point: -31.846°, 115.147°
# CPU times: user 1.71 s, sys: 804 ms, total: 2.51 s
# Wall time: 4.19 s
#                    u         v     speed   direction
# TIME
# 2016-01-01 -0.158464  0.200614  0.255649  321.695011
# 2016-01-02 -0.108298  0.178172  0.208503  328.707509
# 2016-01-03 -0.055664  0.107473  0.121033  332.618615
# 2016-01-04 -0.025718  0.064617  0.069547  338.297171
# 2016-01-05 -0.025252  0.021875  0.033409  310.901078
# ...              ...       ...       ...         ...
# 2016-12-25 -0.182235  0.401189  0.440638  335.570728
# 2016-12-26 -0.182811  0.559489  0.588598  341.905361
# 2016-12-27 -0.189869  0.557260  0.588718  341.185005
# 2016-12-28 -0.108216  0.402577  0.416868  344.954113
# 2016-12-29 -0.032511  0.209840  0.212343  351.192922
#
# [364 rows x 4 columns]
