# %% [markdown]
# ## Access Satellite Net Primary Productivity Gsm 1Day Snpp data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_chlorophylla_gsm_1day_snpp dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/6447f562-9063-4879-8598-ca0b5c4e0175).
#
# 📌 The point of truth for this notebook is [on GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/satellite_chlorophylla_gsm_1day_snpp.ipynb).

# %%
dataset_name = "satellite_chlorophylla_gsm_1day_snpp"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()
# Out:
# Using CPython 3.12.6 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Audited 240 packages in 54ms
# ✅ Local version 0.2.1 is up to date (remote: 0.2.1)

# %%
from DataQuery import GetAodn

# %% [markdown]
# # Understanding the Dataset

# %%
aodn = GetAodn()
dname = f'{dataset_name}.zarr'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 838 ms, sys: 125 ms, total: 963 ms
# Wall time: 1.51 s

# %%
ds = aodn_dataset.zarr_store
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 1045 ;
# 	latitude = 9601 ;
# 	longitude = 13601 ;
#
# variables:
# 	float64 chl_gsm(time, latitude, longitude) ;
# 		chl_gsm:flag_applied = HISATZEN HIGLINT LAND CLDICE NAVFAIL ;
# 		chl_gsm:long_name = Chlorophyll Concentration, GSM model ;
# 		chl_gsm:units = mg/m^3 ;
# 	<U39 filename(time) ;
# 	float64 latitude(latitude) ;
# 		latitude:axis = Y ;
# 		latitude:long_name = latitude ;
# 		latitude:standard_name = latitude ;
# 		latitude:units = degrees_north ;
# 	float64 longitude(longitude) ;
# 		longitude:axis = X ;
# 		longitude:long_name = longitude ;
# 		longitude:standard_name = longitude ;
# 		longitude:units = degrees_east ;
# 	datetime64[ns] time(time) ;
# 		time:axis = T ;
# 		time:long_name = time ;
# 		time:standard_name = time ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:history = File initialised at 2025-01-26T18:25:07.571441
# Initialised var chl_gsm at 2025-01-26T18:26:33.318012
# ...

# %% [markdown]
# ## Plot time coverage

# %%
aodn_dataset.get_temporal_extent()
# Out:
# (Timestamp('2022-05-21 05:30:00'), Timestamp('2025-04-14 05:30:00'))

# %%
aodn_dataset.plot_time_coverage()

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = aodn_dataset.get_timeseries_data(var_name='chl_gsm', 
                                                  lat=-40, 
                                                  lon=130, 
                                                  date_start='2024-01-01', 
                                                  date_end='2024-10-31', 
                                                  lon_name_override="longitude", 
                                                  lat_name_override="latitude")
# Out:
# CPU times: user 3.16 s, sys: 463 ms, total: 3.62 s
# Wall time: 6.54 s

# %%
# %%time
time_series_df = aodn_dataset.plot_timeseries(var_name='chl_gsm', 
                                                  lat=-40, 
                                                  lon=130, 
                                                  date_start='2024-01-01', 
                                                  date_end='2024-10-31', 
                                                  lon_name_override="longitude", 
                                                  lat_name_override="latitude")
# Out:
# CPU times: user 2.17 s, sys: 551 ms, total: 2.72 s
# Wall time: 4.71 s

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
time_series_df = aodn_dataset.plot_gridded_variable(var_name='chl_gsm', 
                                                    date_start='2024-02-01', 
                                                    lon_name_override="longitude", 
                                                    lat_name_override="latitude", 
                                                    lon_slice=(140, 150),
                                                    lat_slice=(-50, -30),
                                                    n_days=6, 
                                                    coastline_resolution="110m", 
                                                    log_scale=True)
# Out:
# 2025-06-05 15:13:48,458 - aodn.GetAodn - INFO - Plotting 'Chlorophyll Concentration, GSM model' for 6 time steps.
# 2025-06-05 15:13:55,345 - aodn.GetAodn - WARNING - No valid data for 2024-02-02 05:30:00, skipping plot.
# 2025-06-05 15:13:55,347 - aodn.GetAodn - WARNING - No valid data for 2024-02-03 05:30:00, skipping plot.
# 2025-06-05 15:13:56,399 - aodn.GetAodn - WARNING - No valid data for 2024-02-05 05:30:00, skipping plot.
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:2527: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(
# CPU times: user 11.7 s, sys: 2.89 s, total: 14.6 s
# Wall time: 14.3 s
