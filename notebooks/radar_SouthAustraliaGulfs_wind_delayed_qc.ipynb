# %% [markdown]
# ## Access Radar SouthAustraliaGulfs Wind Delayed Qc data in Zarr
# A jupyter notebook to show how to access and plot the AODN radar_SouthAustraliaGulfs_wind_delayed_qc dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/db049981-3d4e-4cb2-9c4b-e697650845b9).

# %%
dataset_name = "radar_SouthAustraliaGulfs_wind_delayed_qc"

# %%
import xarray as xr
import fsspec

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
# only run once, then restart session if needed
# !pip install uv

import os
import sys

def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

# Get the current directory of the notebook
current_dir = os.getcwd()

# Check if requirements.txt exists in the current directory
local_requirements = os.path.join(current_dir, 'requirements.txt')
if os.path.exists(local_requirements):
    requirements_path = local_requirements
else:
    # Fall back to the online requirements.txt file
    requirements_path = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/requirements.txt'

# Install packages using uv and the determined requirements file
if is_colab():
    import xarray as xr
    xr.set_options(display_style='text')
    os.system(f'uv pip install --system -r {requirements_path}')
else:
    os.system('uv venv')
    os.system(f'uv pip install -r {requirements_path}')
# Out:
# ...
# Using CPython 3.12.6 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Audited 234 packages in 24ms

# %%
import requests
import os
if not os.path.exists('DataQuery.py'):
  print('Downloading DataQuery.py')
  url = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/aodn_cloud_optimised/lib/DataQuery.py'
  response = requests.get(url)
  with open('DataQuery.py', 'w') as f:
      f.write(response.text)

# %%
from DataQuery import plot_gridded_variable, create_timeseries, plot_time_coverage

# %%
# remote zarr dataset
url = f's3://aodn-cloud-optimised/{dataset_name}.zarr/'
ds = xr.open_zarr(fsspec.get_mapper(url, anon=True), chunks=None, consolidated=True)
ds
# Out:
# <xarray.Dataset> Size: 16GB
# Dimensions:               (LATITUDE: 74, LONGITUDE: 102, TIME: 43540)
# Coordinates:
#   * LATITUDE              (LATITUDE) float64 592B -34.82 -34.86 ... -37.45
#   * LONGITUDE             (LONGITUDE) float64 816B 133.0 133.0 ... 137.4 137.4
#   * TIME                  (TIME) datetime64[ns] 348kB 2009-12-02T01:30:00 ......
# Data variables:
#     WDIR                  (TIME, LATITUDE, LONGITUDE) float64 3GB ...
#     WDIR_quality_control  (TIME, LATITUDE, LONGITUDE) float64 3GB ...
#     WWAV                  (TIME, LATITUDE, LONGITUDE) float64 3GB ...
#     WWAV_quality_control  (TIME, LATITUDE, LONGITUDE) float64 3GB ...
#     WWDS                  (TIME, LATITUDE, LONGITUDE) float64 3GB ...
#     WWDS_quality_control  (TIME, LATITUDE, LONGITUDE) float64 3GB ...
#     filename              (TIME) <U49 9MB ...
# Attributes: (12/39)
#     Conventions:                   CF-1.6,IMOS-1.4
# ...

# %% [markdown]
# ## Plot time coverage

# %%
plot_time_coverage(ds, time_var="TIME")

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
plot_gridded_variable(ds, start_date='2009-12-02', var_name='WDIR', n_days=6, coastline_resolution="50m", time_name="TIME", lat_name="LATITUDE", lon_name="LONGITUDE")
# Out:
# Nearest date in dataset: <xarray.DataArray 'TIME' ()> Size: 8B
# array('2009-12-02T01:30:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     TIME     datetime64[ns] 8B 2009-12-02T01:30:00
# Attributes:
#     axis:             T
#     comment:          Given time lies at the middle of the 1 hour averaging p...
#     local_time_zone:  8.0
#     long_name:        time
#     standard_name:    time
#     valid_max:        999999.0
#     valid_min:        0.0
# Variable Long Name: Direction towards which the wind is blowing based on short wave direction
# No valid data for 2009-12-02 01:30:00, skipping this date.
# No valid data for 2010-01-01 00:30:00, skipping this date.
# No data for 2009-12-02 01:30:00, skipping plot.
# No data for 2010-01-01 00:30:00, skipping plot.
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:880: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ...
