# %% [markdown]
# ## Access Diver Survey Metadata QC (Parquet)
# This Jupyter notebook demonstrates how to access and plot diver_survey_metadata_qc data, available as a [Parquet](https://parquet.apache.org) dataset stored on S3.
#
# 🔗 More information about the dataset is available [in the AODN metadata catalogue](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/997c2e15-b345-438f-afac-49a4ac19be38).
#
# 📌 The source of truth for this notebook is maintained on [GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/diver_survey_metadata_qc.ipynb).

# %%
dataset_name = "diver_survey_metadata_qc"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()

# %%
from DataQuery import GetAodn
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:3217: UserWarning: registration of accessor <class 'DataQuery.AODNAccessor'> under name 'aodn' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("aodn")

# %% [markdown]
# # Understanding the Dataset

# %% [markdown]
# ## Understanding Parquet Partitioning
#
# Parquet files can be **partitioned** by one or more columns, which means the data is physically organised into folders based on the values in those columns. This is similar to how databases use indexes to optimise query performance.
#
# Partitioning enables **faster filtering**: when you query data using a partitioned column, only the relevant subset of files needs to be read—improving performance significantly.
#
# For example, if a dataset is partitioned by `"site_code"`, `"timestamp"`, and `"polygon"`, filtering on `"site_code"` allows the system to skip unrelated files entirely.
#
# In this notebook, the `GetAodn` class includes built-in methods to efficiently filter data by **time** and **latitude/longitude** using the **timestamp** and **polygon** partitions. Other partitions can be used for filtering via the `scalar_filter`.
#
# Any filtering on columns that are **not** partitioned can be significantly slower, as all files may need to be scanned. However, the `GetAodn` class provides a `scalar_filter` method that lets you apply these filters at load time—before the data is fully read—helping reduce the size of the resulting DataFrame.
#
# Once the dataset is loaded, further filtering using Pandas is efficient and flexible.
#
# See further below in the notebook for examples of how to filter the data effectively.
#
# To view the actual partition columns for this dataset, run:

# %%
aodn = GetAodn()
dname = f'{dataset_name}.parquet'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 73.5 ms, sys: 16.2 ms, total: 89.7 ms
# Wall time: 8.65 s

# %%
aodn_dataset.dataset.partitioning.schema
# Out:
# timestamp: int32
# polygon: string

# %% [markdown]
# ## List unique partition values

# %%
# %%time
unique_partition_value = aodn_dataset.get_unique_partition_values('timestamp')
print(list(unique_partition_value)[0:2])  # showing a subset only
# Out:
# ['1167609600', '1104537600']
# CPU times: user 8.42 ms, sys: 1.13 ms, total: 9.55 ms
# Wall time: 6.93 ms

# %% [markdown]
# ## Visualise Spatial Extent of the dataset
# This section plots the polygons representing the areas where data is available. It helps to identify and create a bounding box around the regions containing data.

# %%
aodn_dataset.plot_spatial_extent()
# Out:
# /home/lbesnard/miniforge3/envs/AodnCloudOptimised/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:143: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## Get Temporal Extent of the dataset

# %% [markdown]
# Similary to the spatial extent, we're retrieving the minimum and maximum timestamp partition values of the dataset. This is not necessarely accurately representative of the TIME values, as the timestamp partition can be yearly/monthly... but is here to give an idea

# %%
# %%time
aodn_dataset.get_temporal_extent()
# Out:
# CPU times: user 101 ms, sys: 15.2 ms, total: 116 ms
# Wall time: 762 ms
# (Timestamp('1992-03-10 00:00:00'), Timestamp('2025-09-15 15:00:00'))

# %% [markdown]
# ## Read Metadata
#
# For all Parquet datasets, we create a sidecar file named **_common_metadata** in the root of the dataset. This file contains both the dataset-level and variable-level attributes.
# The metadata can be retrieved below as a dictionary, and it will also be included in the pandas DataFrame when using the `get_data` method from the `GetAodn` class.

# %%
metadata = aodn_dataset.get_metadata()
metadata
# Out:
# 2025-11-10 16:56:11,291 - aodn.GetAodn - INFO - Retrieving metadata for imos-data-lab-optimised/diver_survey_metadata_qc.parquet
# {'survey_id': {'type': 'int32'},
#  'country': {'type': 'string'},
#  'area': {'type': 'string'},
#  'location': {'type': 'string'},
#  'site_code': {'type': 'string'},
#  'site_name': {'type': 'string'},
#  'latitude': {'type': 'float32'},
#  'longitude': {'type': 'float32'},
#  'depth': {'type': 'float32'},
#  'survey_date': {'type': 'string'},
#  'latest_surveydate_for_site': {'type': 'bool'},
#  'has_pq_scores_in_db': {'type': 'bool'},
#  'has_rugosity_scores_in_db': {'type': 'bool'},
#  'has_pqs_catalogued_in_db': {'type': 'bool'},
#  'visibility': {'type': 'float32'},
#  'hour': {'type': 'string'},
#  'direction': {'type': 'string'},
#  'survey_latitude': {'type': 'string'},
#  'survey_longitude': {'type': 'string'},
#  'avg_rugosity': {'type': 'float32'},
#  'max_rugosity': {'type': 'float32'},
#  'surface': {'type': 'string'},
#  'program': {'type': 'string'},
#  'pq_zip_url': {'type': 'string'},
#  'old_site_codes': {'type': 'string'},
#  'methods': {'type': 'string'},
#  'geom': {'type': 'string'},
#  'filename': {'type': 'string',
#   'units': '1',
#   'long_name': 'Filename of the source file'},
#  'timestamp': {'type': 'int64',
#   'units': '1',
#   'long_name': 'Partition timestamp'},
#  'polygon': {'type': 'string',
#   'units': '1',
#   'long_name': 'Spatial partition polygon'},
#  'TIME': {'type': 'timestamp[ns]',
#   'units': 'days since 1970-01-01T00:00:00Z',
#   '_FillValue': '',
#   'long_name': 'Derived timestamp'},
#  'global_attributes': {'metadata_uuid': '997c2e15-b345-438f-afac-49a4ac19be38',
#   'dataset_name': 'diver_survey_metadata_qc',
#   'title': 'IMOS - National Reef Monitoring Network Sub-Facility - Survey metadata'}}

# %% [markdown]
# # Data Query and Plot

# %% [markdown]
# ## Create a TIME and BoundingBox filter
#
# This cell loads a subset of the dataset based on a time range and a spatial bounding box. The result is returned as a pandas DataFrame, and basic information about its structure is displayed.

# %%
# %%time
df = aodn_dataset.get_data(date_start='2015-12-01', 
                           date_end='2019-01-01',
                           lat_min=-34, 
                           lat_max=-31, 
                           lon_min=151, 
                           lon_max=153,
                           lat_varname="latitude",
                           lon_varname="longitude",
                           )

df.info()
# Out:
# 2025-11-10 16:56:11,892 - aodn.GetAodn - INFO - Retrieving metadata for imos-data-lab-optimised/diver_survey_metadata_qc.parquet
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371 entries, 0 to 370
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   survey_id                   371 non-null    int32
#  1   country                     371 non-null    object
#  2   area                        371 non-null    object
#  3   location                    371 non-null    object
#  4   site_code                   371 non-null    object
#  5   site_name                   371 non-null    object
#  6   latitude                    371 non-null    float32
#  7   longitude                   371 non-null    float32
#  8   depth                       371 non-null    float32
#  9   survey_date                 371 non-null    object
#  10  latest_surveydate_for_site  371 non-null    bool
#  11  has_pq_scores_in_db         371 non-null    bool
#  12  has_rugosity_scores_in_db   371 non-null    bool
#  13  has_pqs_catalogued_in_db    371 non-null    bool
#  14  visibility                  369 non-null    float32
#  15  hour                        368 non-null    object
#  16  direction                   369 non-null    object
#  17  survey_latitude             16 non-null     object
#  18  survey_longitude            16 non-null     object
#  19  avg_rugosity                2 non-null      float32
#  20  max_rugosity                2 non-null      float32
#  21  surface                     0 non-null      object
#  22  program                     371 non-null    object
#  23  pq_zip_url                  371 non-null    object
#  24  old_site_codes              330 non-null    object
#  25  methods                     371 non-null    object
#  26  geom                        371 non-null    object
#  27  filename                    371 non-null    object
#  28  TIME                        371 non-null    datetime64[ns]
#  29  timestamp                   371 non-null    int32
#  30  polygon                     371 non-null    object
# dtypes: bool(4), datetime64[ns](1), float32(6), int32(2), object(18)
# memory usage: 68.2+ KB
# CPU times: user 115 ms, sys: 16.3 ms, total: 131 ms
# Wall time: 574 ms

# %%
## Download Subsetted Data as CSV

# This cell downloads the filtered dataset as a ZIP-compressed CSV file.  
# The CSV includes metadata at the top as commented lines, and a `FileLink` object is returned to allow downloading directly from the notebook.


df.aodn.download_as_csv()
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/aodn_metadata-uuid_997c2e15-b345-438f-afac-49a4ac19be38_diver_survey_metadata_qc_data-hash_a4d60044.csv.zip

# %%
df
# Out:
#      survey_id    country             area       location site_code  \
# 0    912345923  Australia  New South Wales  Port Stephens      PS13
# 1    912346114  Australia  New South Wales    Cod Grounds       CG1
# 2    912346126  Australia  New South Wales    Cod Grounds       CG1
# 3    912346120  Australia  New South Wales    Cod Grounds      CG10
# 4    912346117  Australia  New South Wales    Cod Grounds      CG11
# ..         ...        ...              ...            ...       ...
# 366  912350788  Australia  New South Wales         Sydney     SYD61
# 367  912350789  Australia  New South Wales         Sydney     SYD61
# 368  912350787  Australia  New South Wales         Sydney     SYD61
# 369  912350786  Australia  New South Wales         Sydney     SYD61
# 370  912353463  Australia  New South Wales         Sydney     SYD68
#
#                     site_name   latitude   longitude  depth survey_date  ...  \
# 0                    Pipeline -32.720001  152.139999    7.5  2015-12-24  ...
# 1      Nth of Pinnacles (662) -31.680000  152.910004   27.0  2016-04-21  ...
# 2      Nth of Pinnacles (662) -31.680000  152.910004   26.0  2016-04-21  ...
# 3         Steves Bommie (668) -31.680000  152.910004   36.0  2016-04-21  ...
# 4              SE lumps (66A) -31.680000  152.910004   30.0  2016-04-19  ...
# ..                        ...        ...         ...    ...         ...  ...
# 366  Cape Banks - Cruwee Cove -34.000000  151.250000    4.5  2018-03-30  ...
# 367  Cape Banks - Cruwee Cove -34.000000  151.250000    6.0  2018-03-30  ...
# 368  Cape Banks - Cruwee Cove -34.000000  151.250000    5.0  2018-03-30  ...
# 369  Cape Banks - Cruwee Cove -34.000000  151.250000    4.0  2018-03-30  ...
# 370       La Perouse Kelp Bed -33.990002  151.229996    3.3  2018-06-16  ...
#
#      surface  program                                pq_zip_url  \
# 0       None      RLS  http://rls.tpac.org.au/pq/912345923/zip/
# 1       None      RLS   http://rls.tpac.org.au/pq/912346114/zip
# 2       None      RLS   http://rls.tpac.org.au/pq/912346126/zip
# 3       None      RLS   http://rls.tpac.org.au/pq/912346120/zip
# 4       None      RLS   http://rls.tpac.org.au/pq/912346117/zip
# ..       ...      ...                                       ...
# 366     None      RLS   http://rls.tpac.org.au/pq/912350788/zip
# 367     None      RLS   http://rls.tpac.org.au/pq/912350789/zip
# 368     None      RLS   http://rls.tpac.org.au/pq/912350787/zip
# 369     None      RLS                                      None
# 370     None      RLS   http://rls.tpac.org.au/pq/912353463/zip
#
#        old_site_codes      methods  \
# 0        tnsw12,tnsw1     1, 12, 2
# 1     8CG_349,1CG_349     1, 13, 2
# 2     8CG_349,1CG_349  0, 1, 13, 2
# 3            10CG_357     1, 13, 2
# 4            11CG_358  0, 1, 13, 2
# ..                ...          ...
# 366              None         1, 2
# 367              None      0, 1, 2
# 368              None         1, 2
# 369              None         1, 2
# 370              None         1, 2
#
#                                                   geom  \
# 0    0101000020E6100000000000E07A04634000000000295C...
# 1    0101000020E6100000000000C01E1D63400000008014AE...
# 2    0101000020E6100000000000C01E1D63400000008014AE...
# 3    0101000020E6100000000000C01E1D63400000008014AE...
# 4    0101000020E6100000000000C01E1D63400000008014AE...
# ..                                                 ...
# 366  0101000020E61000000000000000E86240000000000000...
# 367  0101000020E61000000000000000E86240000000000000...
# 368  0101000020E61000000000000000E86240000000000000...
# 369  0101000020E61000000000000000E86240000000000000...
# 370  0101000020E6100000000000205CE7624000000060B8FE...
#
#                            filename                TIME   timestamp  \
# 0    ep_survey_list_public_data.csv 2015-12-24 00:00:00  1420070400
# 1    ep_survey_list_public_data.csv 2016-04-21 09:00:00  1451606400
# 2    ep_survey_list_public_data.csv 2016-04-21 09:00:00  1451606400
# 3    ep_survey_list_public_data.csv 2016-04-21 10:00:00  1451606400
# 4    ep_survey_list_public_data.csv 2016-04-19 11:00:00  1451606400
# ..                              ...                 ...         ...
# 366  ep_survey_list_public_data.csv 2018-03-30 11:00:00  1514764800
# 367  ep_survey_list_public_data.csv 2018-03-30 11:00:00  1514764800
# 368  ep_survey_list_public_data.csv 2018-03-30 11:00:00  1514764800
# 369  ep_survey_list_public_data.csv 2018-03-30 11:00:00  1514764800
# 370  ep_survey_list_public_data.csv 2018-06-16 10:00:00  1514764800
#
#                                                polygon
# 0    0103000000010000000500000000000000008061400000...
# 1    0103000000010000000500000000000000008061400000...
# 2    0103000000010000000500000000000000008061400000...
# 3    0103000000010000000500000000000000008061400000...
# 4    0103000000010000000500000000000000008061400000...
# ..                                                 ...
# 366  0103000000010000000500000000000000008061400000...
# 367  0103000000010000000500000000000000008061400000...
# 368  0103000000010000000500000000000000008061400000...
# 369  0103000000010000000500000000000000008061400000...
# 370  0103000000010000000500000000000000008061400000...
#
# [371 rows x 31 columns]

# %% [markdown]
# ## Survey Map

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[df["latitude"].mean(), df["longitude"].mean()], zoom_start=7)
marker_cluster = MarkerCluster().add_to(m)

for _, row in df.iterrows():
    popup = folium.Popup(
        f"<b>Site:</b> {row['site_name']}<br>"
        f"<b>Location:</b> {row['location']}<br>"
        f"<b>Depth:</b> {row['depth']} m<br>"
        f"<b>Date:</b> {row['survey_date']}<br>"
        f"<b>Program:</b> {row['program']}<br>"
        f"<b>PQ scores:</b> {row['has_pq_scores_in_db']}<br>"
        f"<b>Rugosity:</b> {row['has_rugosity_scores_in_db']}",
        max_width=300
    )
    folium.CircleMarker(
        location=[row["latitude"], row["longitude"]],
        radius=6,
        color="darkblue",
        fill=True,
        fill_opacity=0.6,
        popup=popup
    ).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66f93946d2663bed729028a0fe1187be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66f93946d2663bed729028a0fe1187be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66f93946d2663bed729028a0fe1187be = L.map(
#                 &quot;map_66f93946d2663bed729028a0fe1187be&quot;,
#                 {
#                     center: [-33.15918731689453, 151.82020568847656],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e94f646a207381223c80ab4281f9e4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e94f646a207381223c80ab4281f9e4a.addTo(map_66f93946d2663bed729028a0fe1187be);
#
#
#             var marker_cluster_1d9c6b7056ded34d9c5b963153fae86f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_071938c2dbcb145b43a2bd75bbf69a7b = L.circleMarker(
#                 [-32.720001220703125, 152.13999938964844],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_1d9c6b7056ded34d9c5b963153fae86f);
#
#
#         var popup_7818d9ca0f93c0042ec7ece40638eb89 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_8bc853247fad35bfbf51bc099d802706 = $(`&lt;div id=&quot;html_8bc853247fad35bfbf51bc099d802706&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Site:&lt;/b&gt; Pipeline&lt;br&gt;&lt;b&gt;Location:&lt;/b&gt; Port Stephens&lt;br&gt;&lt;b&gt;Depth:&lt;/b&gt; 7.5 m&lt;br&gt;&lt;b&gt;Date:&lt;/b&gt; 2015-12-24&lt;br&gt;&lt;b&gt;Program:&lt;/b&gt; RLS&lt;br&gt;&lt;b&gt;PQ scores:&lt;/b&gt; False&lt;br&gt;&lt;b&gt;Rugosity:&lt;/b&gt; False&lt;/div&gt;`)[0];
#                 popup_7818d9ca0f93c0042ec7ece40638eb89.setContent(html_8bc853247fad35bfbf51bc099d802706);
#
#
#
#         circle_marker_071938c2dbcb145b43a2bd75bbf69a7b.bindPopup(popup_7818d9ca0f93c0042ec7ece40638eb89)
#         ;
#
#
#
#
#             var circle_marker_12ca2b7205b006a4ac73718bc00236f0 = L.circleMarker(
#                 [-31.68000030517578, 152.91000366210938],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_1d9c6b7056ded34d9c5b963153fae86f);
#
#
#         var popup_f810152584bc55d42e5b59da58f07f77 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_fcd739cd833a2526096502bbd9bceca7 = $(`&lt;div id=&quot;html_fcd739cd833a2526096502bbd9bceca7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Site:&lt;/b&gt; Nth of Pinnacles (662)&lt;br&gt;&lt;b&gt;Location:&lt;/b&gt; Cod Grounds&lt;br&gt;&lt;b&gt;Depth:&lt;/b&gt; 27.0 m&lt;br&gt;&lt;b&gt;Date:&lt;/b&gt; 2016-04-21&lt;br&gt;&lt;b&gt;Program:&lt;/b&gt; RLS&lt;br&gt;&lt;b&gt;PQ scores:&lt;/b&gt; True&lt;br&gt;&lt;b&gt;Rugosity:&lt;/b&gt; False&lt;/div&gt;`)[0];
#                 popup_f810152584bc55d42e5b59da58f07f77.setContent(html_fcd739cd833a2526096502bbd9bceca7);
#
#
#
#         circle_marker_12ca2b7205b006a4ac73718bc00236f0.bindPopup(popup_f810152584bc55d42e5b59da58f07f77)
#         ;
#
#
#
#
#             var circle_marker_202cea9a73e54876ac4a1e73528532b2 = L.circleMarker(
#                 [-31.6800003

# %%
from folium.plugins import HeatMap

m = folium.Map(location=[df["latitude"].mean(), df["longitude"].mean()], zoom_start=7)
HeatMap(df[["latitude", "longitude"]].values.tolist(), radius=10, blur=15).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c176f44e0955c8713bf9b8c064e602d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c176f44e0955c8713bf9b8c064e602d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c176f44e0955c8713bf9b8c064e602d1 = L.map(
#                 &quot;map_c176f44e0955c8713bf9b8c064e602d1&quot;,
#                 {
#                     center: [-33.15918731689453, 151.82020568847656],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a2a540bb57aa6e42cf61571f94fed32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1a2a540bb57aa6e42cf61571f94fed32.addTo(map_c176f44e0955c8713bf9b8c064e602d1);
#
#
#             var heat_map_109d5edbf9517b9142c5f5bdd53ae99f = L.heatLayer(
#                 [[-32.720001220703125, 152.13999938964844], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-31.719999313354492, 152.8800048828125], [-31.719999313354492, 152.8800048828125], [-31.729999542236328, 152.8699951171875], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-31.68000030517578, 152.91000366210938], [-33.45000076293945, 151.4499969482422], [-32.599998474121094, 152.32000732421875], [-32.599998474121094, 152.32000732421875], [-32.720001220703125, 152.13999938964844], [-32.720001220703125, 152.13999938964844], [-32.720001220703125, 152.13999938964844], [-32.720001220703125, 152.14999389648438], [-32.720001220703125, 152.14999389648438], [-32.720001220703125, 152.14999389648438], [-32.720001220703125, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.14999389648438], [-32.709999084472656, 152.17999267578125], [-32.619998931884766, 152.3300018310547], [-32.619998931884766, 152.3300018310547], [-32.619998931884766, 152.3300018310547], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.790000915527344, 152.11000061035156], [-32.790000915527344, 152.11000061035156], [-32.790000915527344, 152.11000061035156], [-32.790000915527344, 152.11000061035156], [-32.689998626708984, 152.22000122070312], [-32.689998626708984, 152.22000122070312], [-32.689998626708984, 152.22000122070312], [-32.689998626708984, 152.22999572753906], [-32.689998626708984, 152.22999572753906], [-32.689998626708984, 152.22000122070312], [-32.7400016784668, 152.19000244140625], [-32.7400016784668, 152.19000244140625], [-32.7400016784668, 152.19000244140625], [-32.7400016784668, 152.19000244140625], [-32.7400016784668, 152.19000244140625], [-32.599998474121094, 152.32000732421875], [-32.599998474121094, 152.32000732421875], [-32.619998931884766, 152.3300018310547], [-32.619998931884766, 152.3300018310547], [-32.619998931884766, 152.3300018310547], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.709999084472656, 152.16000366210938], [-32.75, 152.1699981689453], [-33.9900016784668, 151.22999572753906], [-33.9900016784668, 151.22999572753906], [-33.9900016784668, 151.22999572753906], [-33.9900016784668, 151.22999572753906], [-33.9900016784668, 151.22999572753906], [-33.9900016784668, 151.22999572753906], [-33.9900016784668, 151.229
