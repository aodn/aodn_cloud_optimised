# %% [markdown]
# ## Access Satellite Ghrsst L3S 1Month Daytime Single Sensor Australia data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_ghrsst_l3s_1month_daytime_single_sensor_australia dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/b8e9f613-9611-4692-a958-07f100d2c763).

# %%
dataset_name = "satellite_ghrsst_l3s_1month_daytime_single_sensor_australia"

# %%
import xarray as xr
import fsspec

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
# only run once, then restart session if needed
# !pip install uv

import os
import sys

def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

# Get the current directory of the notebook
current_dir = os.getcwd()

# Check if requirements.txt exists in the current directory
local_requirements = os.path.join(current_dir, 'requirements.txt')
if os.path.exists(local_requirements):
    requirements_path = local_requirements
else:
    # Fall back to the online requirements.txt file
    requirements_path = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/requirements.txt'

# Install packages using uv and the determined requirements file
if is_colab():
    xr.set_options(display_style='text')
    os.system(f'uv pip install --system -r {requirements_path}')
else:
    os.system('uv venv')
    os.system(f'uv pip install -r {requirements_path}')
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> This command has been disabled as it tries to modify the immutable
#     `/nix/store` filesystem.
#
#     To use Python with Nix and nixpkgs, have a look at the online documentation:
#     <https://nixos.org/manual/nixpkgs/stable/#python>.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# Using CPython 3.13.1 interpreter at: /home/linuxbrew/.linuxbrew/opt/python@3.13/bin/python3.13
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Audited 230 packages in 30ms

# %%
import requests
import os
if not os.path.exists('DataQuery.py'):
  print('Downloading DataQuery.py')
  url = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/aodn_cloud_optimised/lib/DataQuery.py'
  response = requests.get(url)
  with open('DataQuery.py', 'w') as f:
      f.write(response.text)

# %%
from DataQuery import plot_gridded_variable, create_timeseries, plot_time_coverage

# %%
# remote zarr dataset
url = f's3://aodn-cloud-optimised/{dataset_name}.zarr/'
ds = xr.open_zarr(fsspec.get_mapper(url, anon=True), consolidated=True)
ds
# Out:
# <xarray.Dataset> Size: 519GB
# Dimensions:                  (time: 370, lat: 4500, lon: 6000)
# Coordinates:
#   * lat                      (lat) float32 18kB 19.99 19.97 ... -69.97 -69.99
#   * lon                      (lon) float32 24kB 70.01 70.03 ... 190.0 190.0
#   * time                     (time) datetime64[ns] 3kB 1992-03-16T03:20:00 .....
# Data variables:
#     dt_analysis              (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     l2p_flags                (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     quality_level            (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     satellite_zenith_angle   (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     sea_surface_temperature  (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     sses_bias                (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     sses_count               (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     sses_standard_deviation  (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     sst_count                (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     sst_dtime                (time, lat, lon) float64 80GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     sst_mean                 (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
#     sst_standard_deviation   (time, lat, lon) float32 40GB dask.array<chunksize=(5, 500, 500), meta=np.ndarray>
# Attributes: (12/47)
#     Conventions:                CF-1.6
#     Metadata_Conventions:       Unidata Dataset Discovery v1.0
#     Metadata_Link:              TBA
#     acknowledgment:             Any use of these data requires the following ...
#     cdm_data_type:              grid
#     comment:                    HRPT AVHRR experimental L3 retrieval produced...
#     ...                         ...
#     summary:                    Skin SST retrievals produced from stitching t...
#     time_coverage_end:          20220131T031009Z
#     time_coverage_start:        20211231T211933Z
#     title:                      IMOS L3S Daytime gridded multiple-sensor mult...
#     uuid:                       a82ea3e0-9943-40c9-bb34-f7dad0eba957
#     westernmost_longitude:      70.01000213623047

# %% [markdown]
# ## Plot time coverage

# %%
plot_time_coverage(ds)

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = create_timeseries(ds, 'sea_surface_temperature', lat=-40, lon=130, start_time='2007-12-01', end_time='2008-12-31')
# Out:
# CPU times: user 953 ms, sys: 168 ms, total: 1.12 s
# Wall time: 1.9 s

# %% [markdown]
# ## Plot a gridded variable

# %%
plot_gridded_variable(ds, start_date='2008-06-01', lon_slice=(120, 150), lat_slice=(-50, -30), var_name='sea_surface_temperature', n_days=6, coastline_resolution="50m")
# Out:
# Nearest date in dataset: <xarray.DataArray 'time' ()> Size: 8B
# array('2008-06-15T15:20:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2008-06-15T15:20:00
# Attributes:
#     axis:           T
#     comment:        A typical reference time for data
#     long_name:      reference time of sst file
#     standard_name:  time
# Variable Long Name: sea surface skin temperature
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:838: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
