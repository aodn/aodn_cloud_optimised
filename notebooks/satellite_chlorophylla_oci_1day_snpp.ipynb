# %% [markdown]
# ## Access Satellite Chlorophyll-a OCI 1Day SNPP data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_chlorophylla_oci_1day_snpp dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/d7f9eb3f-b81e-4421-8c75-761ffb33db5d).
#
# 📌 The point of truth for this notebook is [on GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/satellite_chlorophylla_oci_1day_snpp.ipynb).

# %%
dataset_name = "satellite_chlorophylla_oci_1day_snpp"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()
# Out:
# Using CPython 3.12.11 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Using Python 3.12.11 environment at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised
# Audited 256 packages in 32ms
# ✅ Local version 0.2.4 is up to date (remote: 0.2.4)

# %%
from DataQuery import GetAodn
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:2989: UserWarning: registration of accessor <class 'DataQuery.AODNAccessor'> under name 'aodn' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("aodn")

# %% [markdown]
# # Understanding the Dataset

# %%
aodn = GetAodn()
dname = f'{dataset_name}.zarr'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 533 ms, sys: 87.6 ms, total: 621 ms
# Wall time: 2.63 s

# %%
ds = aodn_dataset.zarr_store
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 1045 ;
# 	latitude = 9601 ;
# 	longitude = 13601 ;
#
# variables:
# 	float64 chl_oci(time, latitude, longitude) ;
# 		chl_oci:flag_applied = HISATZEN HIGLINT LAND CLDICE NAVFAIL ;
# 		chl_oci:long_name = Chlorophyll Concentration, OCI Algorithm ;
# 		chl_oci:units = mg/m^3 ;
# 	<U39 filename(time) ;
# 	float64 l2_flags(time, latitude, longitude) ;
# 		l2_flags:flag_applied = HISATZEN HIGLINT LAND CLDICE NAVFAIL ;
# 		l2_flags:flag_masks = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912, 1073741824, -2147483648] ;
# 		l2_flags:flag_meanings = ATMFAIL LAND PRODWARN HIGLINT HILT HISATZEN COASTZ SPARE STRAYLIGHT CLDICE COCCOLITH TURBIDW HISOLZEN SPARE LOWLW CHLFAIL NAVWARN ABSAER SPARE MAXAERITER MODGLINT CHLWARN ATMWARN SPARE SEAICE NAVFAIL FILTER SPARE SPARE HIPOL PRODFAIL SPARE ;
# 		l2_flags:long_name = Level-2 Processing Flags ;
# 		l2_flags:units = 1 ;
# 	float64 latitude(latitude) ;
# 		latitude:axis = Y ;
# 		latitude:long_name = latitude ;
# 		latitude:standard_name = latitude ;
# 		latitude:units = degrees_north ;
# 	float64 longitude(longitude) ;
# 		longitude:axis = X ;
# 		longitude:long_name = longitude ;
# 		longitude:standard_name = longitude ;
# 		longitude:units = degrees_east ;
# 	datetime64[ns] time(time) ;
# 		time:axis = T ;
# 		time:long_name = time ;
# 		time:standard_name = time ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:NCO = netCDF Operators version 5.0.6 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco) ;
# 	:history = Mon Jan 27 05:30:18 2025: ncks -A -v l2_flags -o V20250101.L2OC_VIIRS.aust.chl_oci.nc V20250101.L2OC_VIIRS.aust.l2_flags.nc
# File initialised at 2025-01-26T18:25:07.571441
# Initialised var chl_oci at 2025-01-26T18:25:07.952242
# Add Granule V20250101_0212.20250126142344.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:14.875086
# Add Granule V20250101_0218.20250126141745.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:16.483455
# Add Granule V20250101_0224.20250126140942.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:18.491774
# Add Granule V20250101_0230.20250126140819.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:20.008247
# Add Granule V20250101_0354.20250126140726.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:23.462690
# Add Granule V20250101_0400.20250126140439.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:25.547834
# Add Granule V20250101_0406.20250126135442.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:27.005275
# Add Granule V20250101_0412.20250126135238.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:28.190730
# Add Granule V20250101_0536.20250126135222.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:30.957675
# Add Granule V20250101_0542.20250126135100.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:33.023444
# Add Granule V20250101_0548.20250126133939.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:34.671524
# Add Granule V20250101_0718.20250126133840.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:37.415530
# Add Granule V20250101_0724.20250126133500.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:38.937281
# Add Granule V20250101_0730.20250126133343.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:40.437991
# Add Granule V20250101_0854.20250126132235.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:41.973248
# Add Granule V20250101_0900.20250126132221.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:43.909321
# Add Granule V20250101_0906.20250126132013.L2OC_VIIRS.chl_oci.nc at 2025-01-26T18:25:44.621033 ;
# 	:history_of_appended_files = Mon Jan 27 05:30:18 2025: Appended file V20250101.L2OC_VIIRS.aust.l2_flags.nc had following "history" attribute:
# File initialised at 2025-01-26T18:25:07.571441
# Initialised var l2_flags at 2025-01-26T18:29:37.214574
# Add Granule V20250101_0212.20250126142344.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:39.306953
# Add Granule V20250101_0218.20250126141745.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:39.801433
# Add Granule V20250101_0224.20250126140942.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:40.395472
# Add Granule V20250101_0230.20250126140819.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:40.803249
# Add Granule V20250101_0354.20250126140726.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:41.622757
# Add Granule V20250101_0400.20250126140439.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:42.257046
# Add Granule V20250101_0406.20250126135442.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:42.811004
# Add Granule V20250101_0412.20250126135238.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:43.119287
# Add Granule V20250101_0536.20250126135222.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:44.048684
# Add Granule V20250101_0542.20250126135100.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:44.656089
# Add Granule V20250101_0548.20250126133939.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:45.161002
# Add Granule V20250101_0718.20250126133840.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:46.053421
# Add Granule V20250101_0724.20250126133500.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:46.757995
# Add Granule V20250101_0730.20250126133343.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:47.226858
# Add Granule V20250101_0854.20250126132235.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:47.591047
# Add Granule V20250101_0900.20250126132221.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:48.022243
# Add Granule V20250101_0906.20250126132013.L2OC_VIIRS.l2_flags.nc at 2025-01-26T18:29:48.187045
#  ;
# 	:source_path = imos-srs/archive/oc/snpp/v202303/1d/2025/01/V20250101.L2OC_VIIRS.aust.chl_oci.nc ;
# }

# %% [markdown]
# ## Plot time coverage

# %%
aodn_dataset.get_temporal_extent()
# Out:
# (Timestamp('2022-05-21 05:30:00'), Timestamp('2025-04-14 05:30:00'))

# %%
aodn_dataset.plot_time_coverage()

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = aodn_dataset.get_timeseries_data(var_name='chl_oci', 
                                                  lat=-44, 
                                                  lon=147, 
                                                  date_start='2022-05-22', 
                                                  date_end='2023-12-31', 
                                                  lon_name_override="longitude", 
                                                  lat_name_override="latitude")
# Out:
# CPU times: user 3.2 s, sys: 660 ms, total: 3.86 s
# Wall time: 14.1 s

# %%
# %%time
time_series_df = aodn_dataset.plot_timeseries(var_name='chl_oci', 
                                                  lat=-44, 
                                                  lon=147, 
                                                  date_start='2022-05-22', 
                                                  date_end='2023-12-31', 
                                                  lon_name_override="longitude", 
                                                  lat_name_override="latitude")
# Out:
# CPU times: user 2.95 s, sys: 710 ms, total: 3.66 s
# Wall time: 15.3 s

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
time_series_df = aodn_dataset.plot_gridded_variable(var_name='chl_oci', 
                                                    date_start='2022-05-22', 
                                                    lon_name_override="longitude", 
                                                    lat_name_override="latitude", 
                                                    lon_slice=(140, 150),
                                                    lat_slice=(-50, -36),
                                                    n_days=6, 
                                                    coastline_resolution="50m", 
                                                    log_scale=True)
# Out:
# 2025-08-11 17:14:12,177 - aodn.GetAodn - INFO - Plotting 'Chlorophyll Concentration, OCI Algorithm' for 6 time steps.
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:2591: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(
# CPU times: user 10.9 s, sys: 4.95 s, total: 15.8 s
# Wall time: 23.5 s
