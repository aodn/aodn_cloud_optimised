# %% [markdown]
# ## Access Mooring Acidification Realtime QC (Parquet)
# This Jupyter notebook demonstrates how to access and plot mooring_acidification_realtime_qc data, available as a [Parquet](https://parquet.apache.org) dataset stored on S3.
#
# 🔗 More information about the dataset is available [in the AODN metadata catalogue](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/4d3d4aca-472e-4616-88a5-df0f5ab401ba).
#
# 📌 The source of truth for this notebook is maintained on [GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/mooring_acidification_realtime_qc.ipynb).

# %%
dataset_name = "mooring_acidification_realtime_qc"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()

# %%
from DataQuery import GetAodn

# %% [markdown]
# # Understanding the Dataset

# %% [markdown]
# ## Understanding Parquet Partitioning
#
# Parquet files can be **partitioned** by one or more columns, which means the data is physically organised into folders based on the values in those columns. This is similar to how databases use indexes to optimise query performance.
#
# Partitioning enables **faster filtering**: when you query data using a partitioned column, only the relevant subset of files needs to be read—improving performance significantly.
#
# For example, if a dataset is partitioned by `"site_code"`, `"timestamp"`, and `"polygon"`, filtering on `"site_code"` allows the system to skip unrelated files entirely.
#
# In this notebook, the `GetAodn` class includes built-in methods to efficiently filter data by **time** and **latitude/longitude** using the **timestamp** and **polygon** partitions. Other partitions can be used for filtering via the `scalar_filter`.
#
# Any filtering on columns that are **not** partitioned can be significantly slower, as all files may need to be scanned. However, the `GetAodn` class provides a `scalar_filter` method that lets you apply these filters at load time—before the data is fully read—helping reduce the size of the resulting DataFrame.
#
# Once the dataset is loaded, further filtering using Pandas is efficient and flexible.
#
# See further below in the notebook for examples of how to filter the data effectively.
#
# To view the actual partition columns for this dataset, run:

# %%
aodn = GetAodn()
dname = f'{dataset_name}.parquet'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 63.4 ms, sys: 19.4 ms, total: 82.8 ms
# Wall time: 8.71 s

# %%
aodn_dataset.dataset.partitioning.schema
# Out:
# site_code: string
# timestamp: int32
# polygon: string

# %% [markdown]
# ## List unique partition values

# %%
# %%time
unique_partition_value = aodn_dataset.get_unique_partition_values('site_code')
print(list(unique_partition_value))  # showing a subset only
# Out:
# ['NRSYON', 'GBRWIS', 'NRSKAI', 'NRSMAI']
# CPU times: user 3.49 ms, sys: 141 µs, total: 3.63 ms
# Wall time: 2.85 ms

# %% [markdown]
# ## Visualise Spatial Extent of the dataset
# This section plots the polygons representing the areas where data is available. It helps to identify and create a bounding box around the regions containing data.

# %%
aodn_dataset.plot_spatial_extent()
# Out:
# /home/lbesnard/miniforge3/envs/AodnCloudOptimised/lib/python3.12/site-packages/cartopy/mpl/feature_artist.py:143: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## Get Temporal Extent of the dataset

# %% [markdown]
# Similary to the spatial extent, we're retrieving the minimum and maximum timestamp partition values of the dataset. This is not necessarely accurately representative of the TIME values, as the timestamp partition can be yearly/monthly... but is here to give an idea

# %%
# %%time
aodn_dataset.get_temporal_extent()
# Out:
# CPU times: user 94.3 ms, sys: 39.2 ms, total: 133 ms
# Wall time: 548 ms
# (Timestamp('2011-04-19 23:00:00'), Timestamp('2025-10-28 00:00:00'))

# %% [markdown]
# ## Read Metadata
#
# For all Parquet datasets, we create a sidecar file named **_common_metadata** in the root of the dataset. This file contains both the dataset-level and variable-level attributes.
# The metadata can be retrieved below as a dictionary, and it will also be included in the pandas DataFrame when using the `get_data` method from the `GetAodn` class.

# %%
metadata = aodn_dataset.get_metadata()
metadata
# Out:
# 2025-10-30 10:31:16,830 - aodn.GetAodn - INFO - Retrieving metadata for imos-data-lab-optimised/mooring_acidification_realtime_qc.parquet
# {'TIME': {'type': 'timestamp[ns]',
#   'standard_name': 'time',
#   'long_name': 'time',
#   'valid_min': 0.0,
#   'valid_max': 90000.0,
#   'axis': 'T'},
#  'LATITUDE': {'type': 'double',
#   'standard_name': 'latitude',
#   'long_name': 'latitude',
#   'units': 'degrees_north',
#   'valid_min': -90.0,
#   'valid_max': 90.0,
#   'axis': 'Y',
#   'reference_datum': 'geographical coordinates, WGS84 projection'},
#  'LONGITUDE': {'type': 'double',
#   'standard_name': 'longitude',
#   'long_name': 'longitude',
#   'units': 'degrees_east',
#   'valid_min': -180.0,
#   'valid_max': 180.0,
#   'axis': 'X',
#   'reference_datum': 'geographical coordinates, WGS84 projection'},
#  'XCO2_WATER': {'type': 'float',
#   'long_name': 'mole_fraction_of_carbon_dioxide_in_sea_water',
#   'units': 'ppm',
#   'ancillary_variables': 'XCO2_WATER_standard_deviation'},
#  'XCO2_WATER_standard_deviation': {'type': 'double',
#   'long_name': 'mole_fraction_of_carbon_dioxide_in_sea_water standard_deviation',
#   'units': 'ppm'},
#  'XCO2_AIR': {'type': 'float',
#   'standard_name': 'mole_fraction_of_carbon_dioxide_in_air',
#   'long_name': 'mole_fraction_of_carbon_dioxide_in_air',
#   'units': 'ppm',
#   'ancillary_variables': 'XCO2_AIR_standard_deviation'},
#  'XCO2_AIR_standard_deviation': {'type': 'double',
#   'long_name': 'mole_fraction_of_carbon_dioxide_in_air standard_deviation',
#   'units': 'ppm'},
#  'SSTI': {'type': 'float',
#   'standard_name': 'sea_surface_temperature',
#   'long_name': 'sea_surface_temperature',
#   'units': 'Celsius',
#   'valid_min': -2.5,
#   'valid_max': 40.0},
#  'SSS': {'type': 'float',
#   'standard_name': 'sea_surface_salinity',
#   'long_name': 'sea_surface_salinity',
#   'units': '1e-3',
#   'valid_min': 2.0,
#   'valid_max': 41.0},
#  'TEMP': {'type': 'float',
#   'standard_name': 'sea_surface_temperature',
#   'long_name': 'sea_surface_temperature',
#   'units': 'Celsius',
#   'valid_min': -2.0,
#   'valid_max': 40.0,
#   'sensor': 'SBE 16Plus V2 SeaCAT',
#   'ancillary_variables': 'TEMP_quality_control'},
#  'PSAL': {'type': 'float',
#   'standard_name': 'sea_surface_salinity',
#   'long_name': 'sea surface salinity',
#   'units': '1e-3',
#   'valid_min': 0.0,
#   'valid_max': 42.0,
#   'sensor': 'SBE 16Plus V2 SeaCAT',
#   'ancillary_variables': 'PSAL_quality_control'},
#  'Press_ATM': {'type': 'float',
#   'standard_name': 'air_pressure_at_sea_level',
#   'long_name': 'barometric pressure at sea level',
#   'units': 'kPa',
#   'valid_min': 80.0,
#   'valid_max': 120.0,
#   'ancillary_variables': 'Press_ATM_quality_control'},
#  'xCO2EQ_PPM': {'type': 'float',
#   'long_name': 'mole fraction of CO2 in the equilibrator head space (dry)',
#   'units': '1/10e6',
#   'valid_min': 0.0,
#   'valid_max': 1000.0,
#   'ancillary_variables': 'xCO2EQ_PPM_quality_control',
#   'comment': 'the unit 1/10e6 is also called parts per million (ppm)',
#   'sensor_serial_number': '0115',
#   'sensor': 'Battelle pCO2 Monitoring System'},
#  'xCO2ATM_PPM': {'type': 'float',
#   'long_name': 'mole fraction of CO2 in the atmosphere (dry).',
#   'units': '1/10e6',
#   'valid_min': 0.0,
#   'valid_max': 1000.0,
#   'ancillary_variables': 'xCO2ATM_PPM_quality_control',
#   'comment': 'the unit 1/10e6 is also called parts per million (ppm)',
#   'sensor_serial_number': '0115',
#   'sensor': 'Battelle pCO2 Monitoring System'},
#  'fCO2SW_UATM': {'type': 'float',
#   'long_name': 'fugacity of carbon dioxide at surface water salinity and temperature, 100% humidity',
#   'units': 'microatmospheres',
#   'valid_min': 0.0,
#   'valid_max': 1000.0,
#   'ancillary_variables': 'fCO2SW_UATM_quality_control',
#   'sensor_serial_number': '0139',
#   'sensor': 'Battelle pCO2 Monitoring System'},
#  'DfCO2': {'type': 'float',
#   'long_name': 'Difference between fCO2SW and fCO2ATM',
#   'units': 'microatmospheres',
#   'valid_min': -500.0,
#   'valid_max': 500.0,
#   'ancillary_variables': 'DfCO2_quality_control',
#   'sensor_serial_number': '0139',
#   'sensor': 'Battelle pCO2 Monitoring System'},
#  'DOX1': {'type': 'float',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'long_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water.',
#   'units': 'micromol/l',
#   'valid_min': 0.0,
#   'valid_max': 1000.0,
#   'ancillary_variables': 'DOX1_quality_control',
#   'sensor': 'Aanderaa Optode'},
#  'TPH': {'type': 'float',
#   'standard_name': 'sea_water_ph_reported_on_total_scale',
#   'long_name': 'sea_water_ph_reported_on_total_scale',
#   'units': '1',
#   'valid_min': 5.0,
#   'valid_max': 10.0,
#   'ancillary_variables': 'TPH_quality_control',
#   'sensor': 'SeapHOx-Scripps Institution of Oceanography'},
#  'TIME_quality_control': {'type': 'float',
#   'standard_name': 'time status_flag',
#   'long_name': 'Quality Control flag for time',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'pHt': {'type': 'float',
#   'standard_name': 'sea_water_ph_reported_on_total_scale',
#   'long_name': 'pH_TS_measured(durafet)',
#   'units': '1',
#   'valid_min': 5.0,
#   'valid_max': 10.0,
#   'comment': 'sea_water_ph_reported_on_total_scale',
#   'ancillary_variables': 'pHt_quality_control',
#   'sensor': 'SeapHOx-Scripps Institution of Oceanography'},
#  'TEMP_quality_control': {'type': 'float',
#   'standard_name': 'sea_surface_temperature status_flag',
#   'long_name': 'Quality Control flag for sea_surface_temperature',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'NOMINAL_DEPTH': {'type': 'float',
#   'standard_name': 'depth',
#   'long_name': 'nominal depth',
#   'units': 'm',
#   'axis': 'Z',
#   'reference_datum': 'sea surface',
#   'positive': 'down',
#   'valid_min': -5.0,
#   'valid_max': 1200.0},
#  'PSAL_quality_control': {'type': 'float',
#   'standard_name': 'sea_surface_salinity status_flag',
#   'long_name': 'Quality Control flag for sea_surface_salinity',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'Press_ATM_quality_control': {'type': 'float',
#   'standard_name': 'air_pressure_at_sea_level status_flag',
#   'long_name': 'Quality Control flag for barometric pressure',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'xCO2EQ_PPM_quality_control': {'type': 'float',
#   'long_name': 'Quality Control flag for xCO2EQ_PPM',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'xCO2ATM_PPM_quality_control': {'type': 'float',
#   'long_name': 'Quality Control flag for xCO2ATM_PPM',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'fCO2SW_UATM_quality_control': {'type': 'float',
#   'long_name': 'Quality Control flag for fCO2SW_UATM',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'DfCO2_quality_control': {'type': 'float',
#   'long_name': 'Quality Control flag for DfCO2',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'DOX1_quality_control': {'type': 'float',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water status_flag',
#   'long_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water status_flag',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'TPH_quality_control': {'type': 'float',
#   'standard_name': 'sea_water_ph_reported_on_total_scale status_flag',
#   'long_name': 'sea_water_ph_reported_on_total_scale status_flag',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'pHt_quality_control': {'type': 'float',
#   'standard_name': 'sea_water_ph_reported_on_total_scale status_flag',
#   'long_name': 'pH_TS_measured(durafet) status_flag',
#   'quality_control_conventions': 'WOCE quality control procedure',
#   'quality_control_set': 4.0,
#   'valid_min': 2,
#   'valid_max': 4,
#   'flag_values': [2, 3, 4],
#   'flag_meanings': 'good questionable bad'},
#  'filename': {'type': 'string',
#   'units': '1',
#   'long_name': 'Filename of the source file'},
#  'site_code': {'type': 'string', 'units': '1', 'long_name': 'site code'},
#  'timestamp': {'type': 'int64',
#   'units': '1',
#   'long_name': 'Partition timestamp'},
#  'polygon': {'type': 'string',
#   'units': '1',
#   'long_name': 'Spatial partition polygon'},
#  'global_attributes': {'metadata_uuid': '4d3d4aca-472e-4616-88a5-df0f5ab401ba',
#   'dataset_name': 'mooring_acidification_realtime_qc',
#   'title': 'IMOS - National Mooring Network - Acidification Moorings (AM) Sub-Facility - realtime mode data'}}

# %% [markdown]
# # Data Query and Plot

# %% [markdown]
# ## Create a TIME and BoundingBox filter
#
# This cell loads a subset of the dataset based on a time range and a spatial bounding box. The result is returned as a pandas DataFrame, and basic information about its structure is displayed.

# %%
# %%time
df = aodn_dataset.get_data(date_start='2022-12-01', 
                           date_end='2024-01-01',
                           lat_min=-45, 
                           lat_max=-40, 
                           lon_min=140, 
                           lon_max=155, 
                           )

df.info()
# Out:
# 2025-10-30 10:31:17,478 - aodn.GetAodn - INFO - Retrieving metadata for imos-data-lab-optimised/mooring_acidification_realtime_qc.parquet
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4155 entries, 0 to 4154
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   TIME                           4155 non-null   datetime64[ns]
#  1   LATITUDE                       4155 non-null   float64
#  2   LONGITUDE                      4155 non-null   float64
#  3   XCO2_WATER                     0 non-null      float32
#  4   XCO2_WATER_standard_deviation  0 non-null      float64
#  5   XCO2_AIR                       0 non-null      float32
#  6   XCO2_AIR_standard_deviation    0 non-null      float64
#  7   SSTI                           0 non-null      float32
#  8   SSS                            0 non-null      float32
#  9   filename                       4155 non-null   object
#  10  TEMP                           4155 non-null   float32
#  11  PSAL                           4155 non-null   float32
#  12  Press_ATM                      4155 non-null   float32
#  13  xCO2EQ_PPM                     4155 non-null   float32
#  14  xCO2ATM_PPM                    4155 non-null   float32
#  15  fCO2SW_UATM                    4155 non-null   float32
#  16  DfCO2                          4155 non-null   float32
#  17  DOX1                           4155 non-null   float32
#  18  TPH                            0 non-null      float32
#  19  TIME_quality_control           4155 non-null   float32
#  20  pHt                            0 non-null      float32
#  21  TEMP_quality_control           4155 non-null   float32
#  22  NOMINAL_DEPTH                  4155 non-null   float32
#  23  PSAL_quality_control           4155 non-null   float32
#  24  Press_ATM_quality_control      4155 non-null   float32
#  25  xCO2EQ_PPM_quality_control     4155 non-null   float32
#  26  xCO2ATM_PPM_quality_control    4155 non-null   float32
#  27  fCO2SW_UATM_quality_control    4155 non-null   float32
#  28  DfCO2_quality_control          4155 non-null   float32
#  29  DOX1_quality_control           4155 non-null   float32
#  30  TPH_quality_control            0 non-null      float32
#  31  pHt_quality_control            4155 non-null   float32
#  32  site_code                      4155 non-null   object
#  33  timestamp                      4155 non-null   int32
#  34  polygon                        4155 non-null   object
# dtypes: datetime64[ns](1), float32(26), float64(4), int32(1), object(3)
# memory usage: 698.0+ KB
# CPU times: user 123 ms, sys: 16.2 ms, total: 139 ms
# Wall time: 630 ms

# %%
## Download Subsetted Data as CSV

# This cell downloads the filtered dataset as a ZIP-compressed CSV file.  
# The CSV includes metadata at the top as commented lines, and a `FileLink` object is returned to allow downloading directly from the notebook.


df.aodn.download_as_csv()
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/aodn_metadata-uuid_4d3d4aca-472e-4616-88a5-df0f5ab401ba_mooring_acidification_realtime_qc_data-hash_3e3cff69.csv.zip

# %% [markdown]
# ## Create a TIME and scalar/number filter
#
# This cell filters the dataset by time range and a scalar value (from a Parquet partition) using the `scalar_filter` argument.
# This leverages Parquet partitioning to apply efficient, server-side filtering, which significantly speeds up data loading.

# %%
# %%time
df = aodn_dataset.get_data(date_start='2021-01-01', 
                           date_end='2023-01-01',
                           scalar_filter={'site_code': "NRSMAI"})
df.info()
# Out:
# 2025-10-30 10:31:18,412 - aodn.GetAodn - INFO - Retrieving metadata for imos-data-lab-optimised/mooring_acidification_realtime_qc.parquet
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6646 entries, 0 to 6645
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   TIME                           6646 non-null   datetime64[ns]
#  1   LATITUDE                       6646 non-null   float64
#  2   LONGITUDE                      6646 non-null   float64
#  3   XCO2_WATER                     0 non-null      float32
#  4   XCO2_WATER_standard_deviation  0 non-null      float64
#  5   XCO2_AIR                       0 non-null      float32
#  6   XCO2_AIR_standard_deviation    0 non-null      float64
#  7   SSTI                           0 non-null      float32
#  8   SSS                            0 non-null      float32
#  9   filename                       6646 non-null   object
#  10  TEMP                           6646 non-null   float32
#  11  PSAL                           6646 non-null   float32
#  12  Press_ATM                      6646 non-null   float32
#  13  xCO2EQ_PPM                     6646 non-null   float32
#  14  xCO2ATM_PPM                    6646 non-null   float32
#  15  fCO2SW_UATM                    6646 non-null   float32
#  16  DfCO2                          6646 non-null   float32
#  17  DOX1                           6646 non-null   float32
#  18  TPH                            0 non-null      float32
#  19  TIME_quality_control           6646 non-null   float32
#  20  pHt                            0 non-null      float32
#  21  TEMP_quality_control           6646 non-null   float32
#  22  NOMINAL_DEPTH                  6646 non-null   float32
#  23  PSAL_quality_control           6646 non-null   float32
#  24  Press_ATM_quality_control      6646 non-null   float32
#  25  xCO2EQ_PPM_quality_control     6646 non-null   float32
#  26  xCO2ATM_PPM_quality_control    6646 non-null   float32
#  27  fCO2SW_UATM_quality_control    6646 non-null   float32
#  28  DfCO2_quality_control          6646 non-null   float32
#  29  DOX1_quality_control           6646 non-null   float32
#  30  TPH_quality_control            0 non-null      float32
#  31  pHt_quality_control            6646 non-null   float32
#  32  site_code                      6646 non-null   object
#  33  timestamp                      6646 non-null   int32
#  34  polygon                        6646 non-null   object
# dtypes: datetime64[ns](1), float32(26), float64(4), int32(1), object(3)
# memory usage: 1.1+ MB
# CPU times: user 110 ms, sys: 20.4 ms, total: 130 ms
# Wall time: 630 ms

# %%
df[df['TEMP_quality_control'] == 2].sort_values('TIME').plot(y='TEMP', x='TIME', cmap='RdYlBu_r',
                                                             ylabel=f"{metadata['TEMP']['standard_name']} in {metadata['TEMP']['units']}",
                                                             title=metadata['global_attributes']['title']
                                                             )
# Out:
# <Axes: title={'center': 'IMOS - National Mooring Network - Acidification Moorings (AM) Sub-Facility - realtime mode data'}, xlabel='TIME', ylabel='sea_surface_temperature in Celsius'>
