# %% [markdown]
# ## Access Satellite Chlorophyll-a OC3 1Day Aqua data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_chlorophylla_oc3_1day_aqua dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/d7a14921-8f3f-4522-9a54-e7d1df969c8a).
#
# 📌 The point of truth for this notebook is [on GitHub](https://github.com/aodn/aodn_cloud_optimised/tree/main/notebooks/satellite_chlorophylla_oc3_1day_aqua.ipynb).

# %%
dataset_name = "satellite_chlorophylla_oc3_1day_aqua"

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
import os, requests, importlib.util

open('setup.py', 'w').write(requests.get('https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/setup.py').text)

spec = importlib.util.spec_from_file_location("setup", "setup.py")
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

setup.install_requirements()
setup.load_dataquery()
# Out:
# ✅ Virtual environment already exists, skipping creation.
# Using Python 3.12.6 environment at: /home/lbesnard/github_repo/aodn_cloud_optimised/.venv
# Resolved 201 packages in 87ms
# Checked 201 packages in 1ms
# ✅ Local version 0.3.25 is up to date (remote: 0.3.18)

# %%
from DataQuery import GetAodn
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:4679: UserWarning: registration of accessor <class 'DataQuery.AODNAccessor'> under name 'aodn' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("aodn")

# %% [markdown]
# # Understanding the Dataset

# %%
aodn = GetAodn()
dname = f'{dataset_name}.zarr'
# %time aodn_dataset = aodn.get_dataset(dname)
# Out:
# CPU times: user 1.02 s, sys: 165 ms, total: 1.19 s
# Wall time: 2.83 s

# %%
ds = aodn_dataset.zarr_store
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 8020 ;
# 	latitude = 7001 ;
# 	longitude = 10001 ;
#
# variables:
# 	float64 chl_oc3(time, latitude, longitude) ;
# 		chl_oc3:flag_applied = HISATZEN LAND CLDICE NAVFAIL ;
# 		chl_oc3:long_name = Chlorophyll Concentration, OC3 Algorithm ;
# 		chl_oc3:units = mg/m^3 ;
# 	float64 latitude(latitude) ;
# 		latitude:axis = Y ;
# 		latitude:long_name = latitude ;
# 		latitude:standard_name = latitude ;
# 		latitude:units = degrees_north ;
# 	float64 longitude(longitude) ;
# 		longitude:axis = X ;
# 		longitude:long_name = longitude ;
# 		longitude:standard_name = longitude ;
# 		longitude:units = degrees_east ;
# 	datetime64[ns] time(time) ;
# 		time:axis = T ;
# 		time:long_name = time ;
# 		time:standard_name = time ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:dataset_name = satellite_chlorophylla_oc3_1day_aqua ;
# 	:history = File initialised at 2024-09-17T06:21:12.126924
# Initialised var chl_oc3 at 2024-09-17T06:21:33.550557
# ...

# %% [markdown]
# ## Plot time coverage

# %%
aodn_dataset.get_temporal_extent()
# Out:
# (Timestamp('2002-07-04 05:30:00'), Timestamp('2024-11-15 05:30:00'))

# %%
aodn_dataset.plot_time_coverage()

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = aodn_dataset.get_timeseries_data(var_name='chl_oc3', 
                                                  lat=-40, 
                                                  lon=130, 
                                                  date_start='2002-08-01', 
                                                  date_end='2011-12-31', 
                                                  lon_name_override="longitude", 
                                                  lat_name_override="latitude")
# Out:
# CPU times: user 11.8 s, sys: 1.35 s, total: 13.2 s
# Wall time: 1min

# %%
# %%time
time_series_df = aodn_dataset.plot_timeseries(var_name='chl_oc3', 
                                                  lat=-40, 
                                                  lon=130, 
                                                  date_start='2002-08-01', 
                                                  date_end='2011-12-31', 
                                                  lon_name_override="longitude", 
                                                  lat_name_override="latitude")
# Out:
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:2220: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled = df[self.var_name].resample(resample)
# CPU times: user 11.1 s, sys: 1.21 s, total: 12.3 s
# Wall time: 42 s

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
time_series_df = aodn_dataset.plot_gridded_variable(var_name='chl_oc3', 
                                                    date_start='2024-11-01', 
                                                    lon_name_override="longitude", 
                                                    lat_name_override="latitude", 
                                                    lon_slice=(130, 150),
                                                    lat_slice=(-50, -30),
                                                    n_days=3, 
                                                    coastline_resolution="50m", 
                                                    log_scale=True)
# Out:
# 2026-06-03 14:48:03,378 - aodn.GetAodn - INFO - Plotting 'Chlorophyll Concentration, OC3 Algorithm' for 3 time steps.
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:3785: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(
# CPU times: user 33.6 s, sys: 3.29 s, total: 36.9 s
# Wall time: 58.6 s
