# %% [markdown]
# ## Access Satellite Net Primary Productivity Gsm 1Day Snpp data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_chlorophylla_gsm_1day_snpp dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/6447f562-9063-4879-8598-ca0b5c4e0175).

# %%
dataset_name = "satellite_chlorophylla_gsm_1day_snpp"

# %%
import xarray as xr
import fsspec

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
# only run once, then restart session if needed
# !pip install uv

import os
import sys

def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

# Get the current directory of the notebook
current_dir = os.getcwd()

# Check if requirements.txt exists in the current directory
local_requirements = os.path.join(current_dir, 'requirements.txt')
if os.path.exists(local_requirements):
    requirements_path = local_requirements
else:
    # Fall back to the online requirements.txt file
    requirements_path = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/requirements.txt'

# Install packages using uv and the determined requirements file
if is_colab():
    import xarray as xr
    xr.set_options(display_style='text')
    os.system(f'uv pip install --system -r {requirements_path}')
else:
    os.system('uv venv')
    os.system(f'uv pip install -r {requirements_path}')
# Out:
# ...
# Using CPython 3.12.6 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Audited 234 packages in 34ms

# %%
import requests
import os
if not os.path.exists('DataQuery.py'):
  print('Downloading DataQuery.py')
  url = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/aodn_cloud_optimised/lib/DataQuery.py'
  response = requests.get(url)
  with open('DataQuery.py', 'w') as f:
      f.write(response.text)

# %%
from DataQuery import plot_gridded_variable, create_timeseries, plot_time_coverage

# %%
# remote zarr dataset
url = f's3://aodn-cloud-optimised/{dataset_name}.zarr/'
ds = xr.open_zarr(fsspec.get_mapper(url, anon=True), chunks=None, consolidated=True)
ds
# Out:
# <xarray.Dataset> Size: 1TB
# Dimensions:    (time: 1045, latitude: 9601, longitude: 13601)
# Coordinates:
#   * latitude   (latitude) float64 77kB 12.0 11.99 11.98 ... -59.98 -59.99 -60.0
#   * longitude  (longitude) float64 109kB 78.0 78.01 78.02 ... 180.0 180.0 180.0
#   * time       (time) datetime64[ns] 8kB 2022-05-21T05:30:00 ... 2025-04-14T0...
# Data variables:
#     chl_gsm    (time, latitude, longitude) float64 1TB ...
#     filename   (time) <U39 163kB ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      File initialised at 2025-01-26T18:25:07.571441\nInitialised...
#     source_path:  imos-srs/archive/oc/snpp/v202303/1d/2025/01/V20250101.L2OC_...

# %% [markdown]
# ## Plot time coverage

# %%
plot_time_coverage(ds)

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = create_timeseries(ds, 'chl_gsm', lat=-40, lon=130, start_time='2024-01-01', end_time='2024-10-31', lon_name="longitude", lat_name="latitude")
# Out:
# CPU times: user 3.24 s, sys: 758 ms, total: 4 s
# Wall time: 13.6 s

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
plot_gridded_variable(ds, start_date='2024-02-01', lon_slice=(140, 150), lat_slice=(-50, -30), var_name='chl_gsm', n_days=6, coastline_resolution="110m", lon_name="longitude", lat_name="latitude", log_scale=True)
# Out:
# Nearest date in dataset: <xarray.DataArray 'time' ()> Size: 8B
# array('2024-02-01T05:30:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2024-02-01T05:30:00
# Attributes:
#     axis:           T
#     long_name:      time
#     standard_name:  time
# Variable Long Name: Chlorophyll Concentration, GSM model
# No valid data for 2024-02-02 05:30:00, skipping this date.
# No valid data for 2024-02-03 05:30:00, skipping this date.
# No valid data for 2024-02-05 05:30:00, skipping this date.
# No data for 2024-02-02 05:30:00, skipping plot.
# No data for 2024-02-03 05:30:00, skipping plot.
# No data for 2024-02-05 05:30:00, skipping plot.
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:880: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# CPU times: user 8.46 s, sys: 2.5 s, total: 11 s
# Wall time: 16.5 s
