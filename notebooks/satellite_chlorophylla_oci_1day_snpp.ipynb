# %% [markdown]
# ## Access Satellite Chlorophylla Oci 1Day Snpp data in Zarr
# A jupyter notebook to show how to access and plot the AODN satellite_chlorophylla_oci_1day_snpp dataset available as a [Zarr](https://zarr.dev/) dataset on S3.
#
# More information about the dataset available [here](https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/d7f9eb3f-b81e-4421-8c75-761ffb33db5d).

# %%
dataset_name = "satellite_chlorophylla_oci_1day_snpp"

# %%
import xarray as xr
import fsspec

# %% [markdown]
# ## Install/Update packages and Load common functions

# %%
# only run once, then restart session if needed
# !pip install uv

import os
import sys

def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

# Get the current directory of the notebook
current_dir = os.getcwd()

# Check if requirements.txt exists in the current directory
local_requirements = os.path.join(current_dir, 'requirements.txt')
if os.path.exists(local_requirements):
    requirements_path = local_requirements
else:
    # Fall back to the online requirements.txt file
    requirements_path = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/notebooks/requirements.txt'

# Install packages using uv and the determined requirements file
if is_colab():
    xr.set_options(display_style='text')
    os.system(f'uv pip install --system -r {requirements_path}')
else:
    os.system('uv venv')
    os.system(f'uv pip install -r {requirements_path}')
# Out:
# Requirement already satisfied: uv in /home/lbesnard/miniforge3/envs/AodnCloudOptimised/lib/python3.12/site-packages (0.4.18)
# Using CPython 3.12.6 interpreter at: /home/lbesnard/miniforge3/envs/AodnCloudOptimised/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Audited 234 packages in 38ms

# %%
import requests
import os
if not os.path.exists('DataQuery.py'):
  print('Downloading DataQuery.py')
  url = 'https://raw.githubusercontent.com/aodn/aodn_cloud_optimised/main/aodn_cloud_optimised/lib/DataQuery.py'
  response = requests.get(url)
  with open('DataQuery.py', 'w') as f:
      f.write(response.text)

# %%
from DataQuery import plot_gridded_variable, create_timeseries, plot_time_coverage

# %%
# remote zarr dataset
url = f's3://aodn-cloud-optimised/{dataset_name}.zarr/'

ds = xr.open_zarr(fsspec.get_mapper(url, anon=True), chunks=None, consolidated=True)
ds
# Out:
# <xarray.Dataset> Size: 2TB
# Dimensions:    (time: 1045, latitude: 9601, longitude: 13601)
# Coordinates:
#   * latitude   (latitude) float64 77kB 12.0 11.99 11.98 ... -59.98 -59.99 -60.0
#   * longitude  (longitude) float64 109kB 78.0 78.01 78.02 ... 180.0 180.0 180.0
#   * time       (time) datetime64[ns] 8kB 2022-05-21T05:30:00 ... 2025-04-14T0...
# Data variables:
#     chl_oci    (time, latitude, longitude) float64 1TB ...
#     filename   (time) <U39 163kB ...
#     l2_flags   (time, latitude, longitude) float64 1TB ...
# Attributes:
#     Conventions:                CF-1.6
#     NCO:                        netCDF Operators version 5.0.6 (Homepage = ht...
#     history:                    Mon Jan 27 05:30:18 2025: ncks -A -v l2_flags...
#     history_of_appended_files:  Mon Jan 27 05:30:18 2025: Appended file V2025...
#     source_path:                imos-srs/archive/oc/snpp/v202303/1d/2025/01/V...

# %% [markdown]
# ## Plot time coverage

# %%
plot_time_coverage(ds)

# %% [markdown]
# ## Timeseries at a point

# %%
# %%time
time_series_df = create_timeseries(ds, 'chl_oci', lat=-44, lon=147, start_time='2022-05-22', end_time='2023-12-31', lon_name="longitude", lat_name="latitude")
# Out:
# CPU times: user 6.71 s, sys: 1.59 s, total: 8.3 s
# Wall time: 40.6 s

# %% [markdown]
# ## Plot a gridded variable

# %%
# %%time
plot_gridded_variable(ds, start_date='2022-05-22', lon_slice=(140, 150), lat_slice=(-50, -36), var_name='chl_oci', n_days=6, coastline_resolution="50m", lon_name="longitude", lat_name="latitude", log_scale=True)
# Out:
# Nearest date in dataset: <xarray.DataArray 'time' ()> Size: 8B
# array('2022-05-22T05:30:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2022-05-22T05:30:00
# Attributes:
#     axis:           T
#     long_name:      time
#     standard_name:  time
# Variable Long Name: Chlorophyll Concentration, OCI Algorithm
# /home/lbesnard/github_repo/aodn_cloud_optimised/notebooks/DataQuery.py:880: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# CPU times: user 13.1 s, sys: 4.6 s, total: 17.7 s
# Wall time: 46.6 s
